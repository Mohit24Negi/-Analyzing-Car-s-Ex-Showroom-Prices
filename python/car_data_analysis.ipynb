# %% [markdown]
# <a id="1"></a>
# # <div style="padding:20px;color:white;margin:0;font-size:30px;font-family:Georgia;text-align:center;display:fill;border-radius:5px;background-color:#254E58;overflow:hidden"><b>✨ Analyzing Car's Ex-Showroom Prices. ✨</b></div>

# %% [markdown]
# <h3 align="center" style="font-size: 35px; color: #800080; font-family: Georgia;">
#     <span style="color: #008080;"> Author:</span>
#     <span style="color: black;">Mohit Negi .📄🖋️</span>
# </h3>

# %% [markdown]
# <a id="1"></a>
# # <div style="padding:20px;color:white;margin:0;font-size:35px;font-family:Verdana;text-align:center;display:fill;border-radius:5px;background-color:#254E58;overflow:hidden"><b> 🎬 Introduction 🎬</b></div>

# %% [markdown]
# <div style="border-radius:10px; border:2px solid black; padding:15px; background-color:white; font-size:110%; text-align:left">
#
# <div style="font-family:Georgia; background-color:#F5F5DC; padding:30px; font-size:17px">
#
# <h3 align="left"><font color="purple">📝 Project Description</font></h3>
# <br>
#
# <b>1. Goal:</b>
# The goal of this project is to perform an in-depth <b>Exploratory Data Analysis (EDA)</b> to understand how various car features influence the <b>Ex-Showroom Price</b> and to identify key patterns, trends, and relationships within the data.
# <br><br>
#
# <b>2. Purpose:</b>
# The purpose of this analysis is to extract meaningful insights from a raw dataset containing approximately <b>140 car attributes</b>. These insights help car buyers, sellers, and automotive businesses make <b>informed, data-driven decisions</b> without building a predictive model.
# <br><br>
#
# <b>3. Dataset:</b>
# <a href="https://www.kaggle.com/datasets/harmeetsingh07/exshowroom-price" target="_blank">
# Click here to access the dataset
# </a>
#
# <br><br>
#
# <h3 align="left"><font color="purple">🌟 Business Understanding</font></h3>
# <br>
#
# <b>1.</b> In today’s fast-paced world, <b>personal transportation</b> plays a vital role in improving mobility, saving time, and enhancing convenience. Cars have become an essential resource for individuals and businesses alike.
# <br><br>
#
# <b>2.</b> For the automotive industry, understanding <b>how different vehicle features affect pricing</b> is crucial. Factors such as engine specifications, fuel type, body type, safety features, and comfort features directly impact a car’s market value.
# <br><br>
#
# <b>3.</b> By analyzing these features through exploratory data analysis, businesses can <b>optimize pricing strategies</b>, understand customer preferences, and maintain competitive positioning in the market. At the same time, customers benefit from <b>transparent and fair pricing</b> based on vehicle attributes.
#
# </div>
# </div>

# %% [markdown]
# <a id="1"></a>
# # <div style="padding:20px;color:white;margin:0;font-size:35px;font-family:Verdana;text-align:center;display:fill;border-radius:5px;background-color:#254E58;overflow:hidden"><b> 📚 Importing Libraries 📚</b></div>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

sns.set(style="darkgrid",font_scale=1.2)
pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# -----

# %% [markdown]
# <a id="1"></a>
# # <div style="padding:20px;color:white;margin:0;font-size:35px;font-family:Verdana;text-align:center;display:fill;border-radius:5px;background-color:#254E58;overflow:hidden"><b>⏳ Loading Datset ⏳</b></div>

# %% [markdown]
# ----

# %%
df= pd.read_csv('cars_data.csv', index_col=[0])

# %%
df.head()
# Out:
#    Make      Model  Variant Ex-Showroom_Price Displacement  Cylinders  \
# 0  Tata  Nano Genx       Xt      Rs. 2,92,667       624 cc        2.0
# 1  Tata  Nano Genx       Xe      Rs. 2,36,447       624 cc        2.0
# 2  Tata  Nano Genx  Emax Xm      Rs. 2,96,661       624 cc        2.0
# 3  Tata  Nano Genx      Xta      Rs. 3,34,768       624 cc        2.0
# 4  Tata  Nano Genx       Xm      Rs. 2,72,223       624 cc        2.0
#
#    Valves_Per_Cylinder              Drivetrain Cylinder_Configuration  \
# 0                  2.0  RWD (Rear Wheel Drive)                In-line
# 1                  2.0  RWD (Rear Wheel Drive)                In-line
# 2                  2.0  RWD (Rear Wheel Drive)                In-line
# 3                  2.0  RWD (Rear Wheel Drive)                In-line
# 4                  2.0  RWD (Rear Wheel Drive)                In-line
#
#   Emission_Norm   Engine_Location Fuel_System Fuel_Tank_Capacity Fuel_Type  \
# ...

# %% [markdown]
# -----

# %% [markdown]
# <a id="1"></a>
# # <div style="padding:20px;color:white;margin:0;font-size:35px;font-family:Verdana;text-align:center;display:fill;border-radius:5px;background-color:#254E58;overflow:hidden"><b>🧠 Basic Understanding of Data 🧠</b></div>

# %% [markdown]
# ### 1. Cheking Dimension of Dataset.

# %%
display(df.shape)
# Out:
# (1276, 140)

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# * There are total **1276 Records/Rows** in the dataset.
# * There are total **140 Features/columns** in the dataset.

# %% [markdown]
# ### 2. Generating Basic Information about Data.

# %%
display(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1276 entries, 0 to 1275
# Columns: 140 entries, Make to Electric_Range
# dtypes: float64(6), str(134)
# memory usage: 1.4 MB
# None

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# * There are only **6 Numerical Features** in the dataset.
# * On the other hand we have **134 Categorical features.**

# %% [markdown]
# ### 3. Showing Random Sample of Only Numerical Features.

# %%
df.select_dtypes(include="float").sample(5)
# Out:
#       Cylinders  Valves_Per_Cylinder  Doors  Seating_Capacity  \
# 326         6.0                  4.0    5.0               4.0
# 401         3.0                  4.0    5.0               6.0
# 1161        6.0                  4.0    5.0               5.0
# 596         4.0                  4.0    4.0               8.0
# 1200        4.0                  NaN    5.0               5.0
#
#       Number_of_Airbags  USB_Ports
# 326                 6.0        NaN
# 401                 2.0        NaN
# 1161                8.0        NaN
# 596                 NaN        NaN
# 1200                2.0        NaN

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# * We can clearly oberve that the **USB_Ports** is having only **NaN values** in radom 5 sample.
# * We will **check the missing values** in detail for the other **numerical features.**

# %% [markdown]
# ### 4. Showing Radom Sample of Only Categorical Features.

# %%
df.select_dtypes(include="object").sample(5)
# Out:
#               Make      Model         Variant Ex-Showroom_Price Displacement  \
# 17         Renault       Kwid  Climber 1.0 Mt      Rs. 4,54,490       999 cc
# 5             Tata  Nano Genx             Xma      Rs. 3,14,815       624 cc
# 646       Mahindra    Marazzo        M4 7 Str     Rs. 11,56,471      1497 cc
# 489  Maruti Suzuki      Gypsy        Soft Top      Rs. 6,22,730      1298 cc
# 319            Bmw   7-Series    745Le Xdrive   Rs. 1,65,00,000      2998 cc
#
#                   Drivetrain Cylinder_Configuration Emission_Norm  \
# 17   FWD (Front Wheel Drive)                In-line          BS 6
# 5     RWD (Rear Wheel Drive)                In-line         BS IV
# 646  FWD (Front Wheel Drive)                In-line         BS IV
# 489                      4WD                In-line        BS III
# 319    AWD (All Wheel Drive)                      V          BS 6
#
#          Engine_Location Fuel_System Fuel_Tank_Capacity Fuel_Type   Height  \
# ...

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# * **In the end many attributes** contanins **only missing values.** We will deal with those features while performing **Data Cleaning**.
# * There are many **numerical features** which are having **categorical data-type**. So we have to change their data-types.

# %% [markdown]
# -----

# %% [markdown]
# <div style="background-color:lightblue; padding:15px; border-radius:8px;">
#   <h2 style="text-align:center; margin:0;">🧹Data-Cleaning🧹</h2>
# </div>

# %% [markdown]
# ### 1. Computing Total No. Missing values and % of Missing values.

# %%
null_df=df.isna().sum()[df.isna().sum()>0].to_frame(name= 'Total number of missing values')
null_df['% of missing value']= np.ceil(null_df['Total number of missing values']/len(df)*100)
null_df.sort_values(by='% of missing value', ascending= False)
# Out:
#                                            Total number of missing values  \
# Other_Specs                                                          1266
# Recommended_Tyre_Pressure                                            1266
# Battery                                                              1263
# Electric_Range                                                       1259
# Engine_Type                                                          1242
# ARAI_Certified_Mileage_for_CNG                                       1249
# USB_Ports                                                            1247
# Heads-Up_Display                                                     1225
# 3_Point_Seat-Belt_in_Middle_Rear_Seat                                1225
# Other_specs                                                          1213
# Ambient_Lightning                                                    1220
# Lane_Watch_Camera/_Side_Mirror_Camera                                1210
# ...

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# * **Almost 25 features** are having missing values **more than 70%**. So we can **simply drop these features.**
# * Because if we fill missing values in those attributes our **original data/raw data** will be **totally changed.**

# %% [markdown]
# -----

# %% [markdown]
# ### 2. Dropping Features having Missing values more than 70%.

# %%
cols_to_drop= null_df[null_df['% of missing value']>=70].index.tolist()

# %%
df= df.drop(columns= cols_to_drop)

# %%
display(df.shape)
# Out:
# (1276, 114)

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# * Earlier we were having total **140 features** and we dropped **25 features**.
# * So we are left with only **115 features**.

# %% [markdown]
# ------

# %% [markdown]
# ### 3. Checking duplicate

# %%
df.duplicated().sum()
# Out:
# np.int64(9)

# %%
df.columns.duplicated().any()
# Out:
# np.False_

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# * There are **no duplicate columns** in the **dataframe**.
# * However, the dataset contains **9 duplicate rows**, which are **removed** to maintain **data quality**.

# %% [markdown]
# -----

# %% [markdown]
# ### 4. Droping Duplicates

# %%
df.drop_duplicates(inplace = True)

# %% [markdown]
# ------

# %% [markdown]
# ### 5. Checking Data-Types of Features.

# %%
df.dtypes.to_frame(name="Data-Types")
# Out:
#                                           Data-Types
# Make                                             str
# Model                                            str
# Variant                                          str
# Ex-Showroom_Price                                str
# Displacement                                     str
# Cylinders                                    float64
# Valves_Per_Cylinder                          float64
# Drivetrain                                       str
# Cylinder_Configuration                           str
# Emission_Norm                                    str
# Engine_Location                                  str
# Fuel_System                                      str
# Fuel_Tank_Capacity                               str
# Fuel_Type                                        str
# Height                                           str
# Length                                           str
# Width                                            str
# ...

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# * We are having both **numeircal & categorical Features.** But **mostly categorical Features.**
# * For better and easy cleaning it's better to split the dataframe into **two new data-frames**.
#     1. **`Dataframe having only Categroical Variables.`**
#
#     2. **`Dataframe having only Numerical Variables.`**

# %% [markdown]
# ------

# %% [markdown]
# ### 6. Splliting data-frames into two new data-frames.

# %%
num_df= df.select_dtypes(include='float')
ob_df= df.select_dtypes(include= 'object')

# %%
print('Shape of numerical col', num_df.shape)
print('Shape of Categroical col', ob_df.shape)
# Out:
# Shape of numerical col (1267, 5)
# Shape of Categroical col (1267, 109)

# %% [markdown]
# -----

# %% [markdown]
# <a id="1"></a>
# # <div style="padding:20px;color:white;margin:0;font-size:35px;font-family:Verdana;text-align:center;display:fill;border-radius:5px;background-color:#254E58;overflow:hidden"><b>🧼 Cleaning Categorical Data-Frame 🧼</b></div>

# %% [markdown]
# -----

# %% [markdown]
# ### Displaying random sample of Categorical Data-Frame

# %%
ob_df.sample(3)
# Out:
#      Make                              Model                    Variant  \
# 555  Ford                           Ecosport         1.5L Tdci Ambiente
# 821   NaN  Mercedes-Benz E-Class All Terrain                     E 220D
# 524  Tata                              Nexon  Xza Plus Diesel Dual Tone
#
#     Ex-Showroom_Price Displacement               Drivetrain  \
# 555      Rs. 8,41,000      1498 cc  FWD (Front Wheel Drive)
# 821     Rs. 75,00,000      1950 cc   RWD (Rear Wheel Drive)
# 524     Rs. 11,80,000      1497 cc  FWD (Front Wheel Drive)
#
#     Cylinder_Configuration Emission_Norm      Engine_Location Fuel_System  \
# 555                In-line          BS 6    Front, Transverse   Injection
# 821                      V          BS 6  Front, Longitudinal   Injection
# 524                In-line          BS 6                  NaN   Injection
#
#     Fuel_Tank_Capacity Fuel_Type   Height   Length    Width Body_Type  \
# ...

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# * In the end **most of the features are having only missing values.**
# * There are many **numerical features** which are having **object** data-type but it should be having **numerical data-type.**
#
#  <h3 align="left"><font color=brown> Note:</font></h3>
#
# * There are **total 109 categorical features** but all them are **not relevant for predicting price of car.**
# * So we will **extract** the features which are **relevant to our target feature.**

# %% [markdown]
# ###  Extracting the Relevant Attributes from the Categorical Data-Frame.

# %%
revelant_cols = [
    # Target
    "Ex-Showroom_Price",

    # Identity / Positioning
    "Make",
    "Model",
    "Variant",
    "Body_Type",
    "Emission_Norm",

    # Engine / Performance
    "Fuel_Type",
    "Displacement",
    "Cylinder_Configuration",
    "Fuel_System",
    "Turbocharger",
    "Power",
    "Torque",

    # Size / Weight
    "Length",
    "Width",
    "Height",
    "Wheelbase",
    "Kerb_Weight",
    "Ground_Clearance",

    # Mechanical / Drivetrain
    "Drivetrain",
    "Gears",
    "Front_Suspension",
    "Rear_Suspension",
    "Front_Brakes",
    "Rear_Brakes",

    # Mileage
    "ARAI_Certified_Mileage",
    "City_Mileage",
    "Highway_Mileage",

    # Safety Features
    "Airbags",
    "ABS_(Anti-lock_Braking_System)",
    "EBD_(Electronic_Brake-force_Distribution)",
    "ESP_(Electronic_Stability_Program)",
    "Hill_Assist",
    "ISOFIX_(Child-Seat_Mount)",

    # Comfort / Infotainment
    "Power_Steering",
    "Power_Windows",
    "Central_Locking",
    "Keyless_Entry",
    "Start_/_Stop_Button",
    "Infotainment_Screen",
    "Navigation_System",
    "Bluetooth",
    "Multifunction_Steering_Wheel",
    "Automatic_Headlamps",
    "Rain_Sensing_Wipers",

    # Useful extra
    "Fuel_Tank_Capacity",
    "Boot_Space"
]

# %%
ob_df = ob_df[revelant_cols]

# %%
ob_df.shape
# Out:
# (1267, 47)

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# * All the **Features selected** above are all relevant for **car price prediction.**
# * **Note:**
#     1. **The features selected** are based on the **domain knowledge and expertise of cars.**
#     2. I have selected **only 47 features out of 110 features.**

# %% [markdown]
# ###  Display Random Sample from new Categorical Data-Frame.

# %%
ob_df.sample(2)
# Out:
#     Ex-Showroom_Price     Make                  Model            Variant  \
# 795     Rs. 59,64,321      NaN  Mercedes-Benz E-Class              E220D
# 582     Rs. 14,07,871  Hyundai                  Verna  1.6 Crdi Sx(O) At
#
#     Body_Type Emission_Norm Fuel_Type Displacement Cylinder_Configuration  \
# 795     Sedan         BS IV    Diesel      2987 cc                      V
# 582     Sedan         BS IV    Diesel      1582 cc                In-line
#
#     Fuel_System Turbocharger            Power              Torque   Length  \
# 795   Injection          Yes  268.7PS@3800rpm       620Nm@1600rpm  5063 mm
# 582   Injection          NaN    128ps@4000rpm  260Nm@1500-3000rpm  4440 mm
#
#        Width   Height Wheelbase Kerb_Weight Ground_Clearance  \
# 795  1860 mm  1494 mm   3079 mm         NaN           155 mm
# 582  1729 mm  1445 mm   2600 mm         NaN           165 mm
#
#                   Drivetrain Gears  \
# 795   RWD (Rear Wheel Drive)   NaN
# ...

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# * We can observe that **most of attributes** are having **missing values.**
# * There are many **many attributes which are storing numerical values** but they are having **categorical data-type.**So we have to clean those attributes

# %% [markdown]
# #### Total number of missing values and % of missing values.

# %%
null_df = ob_df.isna().sum().to_frame(name = 'Total number of missing values')
null_df['% of missing values'] = np.ceil(null_df['Total number of missing values']/len(df)*100)
null_df.sort_values(by = "Total number of missing values", ascending= False)
# Out:
#                                            Total number of missing values  \
# Rain_Sensing_Wipers                                                   798
# Hill_Assist                                                           795
# Highway_Mileage                                                       792
# ESP_(Electronic_Stability_Program)                                    778
# Automatic_Headlamps                                                   773
# Start_/_Stop_Button                                                   676
# ISOFIX_(Child-Seat_Mount)                                             657
# Turbocharger                                                          618
# Navigation_System                                                     593
# City_Mileage                                                          554
# Infotainment_Screen                                                   462
# Kerb_Weight                                                           365
# ...

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# * Almost **every feature** is **having missing values.**
# * So we have to fill these **features missing values** with **suitable values.**
# * Since There are **too many attributes** its better to **clean attributes step by step.**

# %% [markdown]
# -----

# %% [markdown]
# <div style="background-color:lightgreen; padding:15px; border-radius:8px;">
#   <h2 style="text-align:center; margin:0;">Cleaning Ex-Showroom_Price column</h2>
# </div>

# %% [markdown]
# -----

# %% [markdown]
# #### Displaying 5 Random values.

# %%
ob_df[["Ex-Showroom_Price"]].sample(5)
# Out:
#     Ex-Showroom_Price
# 485      Rs. 8,77,300
# 546     Rs. 10,59,742
# 156      Rs. 7,32,113
# 819     Rs. 72,46,802
# 586      Rs. 9,15,128

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# * **Ex-Showroom Price** is having the **Currency** value combined with the **price values**.
# * Hence we have to **extract** only the **numerical values** and **change its data-type.**

# %% [markdown]
# #### Filling Missing values in Ex-Showroom_Price column.

# %%
ob_df["Ex-Showroom_Price"] = ob_df["Ex-Showroom_Price"].str.replace("Rs.", "").str.replace(",","")

# %%
ob_df[["Ex-Showroom_Price"]].sample(5)
# Out:
#      Ex-Showroom_Price
# 927             993997
# 242            3153500
# 502            1089000
# 940            1035000
# 1054          18844000

# %% [markdown]
# #### Converting Ex-Showroom_Price datatype to integer.

# %%
ob_df["Ex-Showroom_Price"]= ob_df["Ex-Showroom_Price"].astype(int)

# %% [markdown]
# #### Checking missing values in Ex-Showroom_Price column.

# %%
print("total number of missing values in Ex-Showroom_Price column: ", ob_df["Ex-Showroom_Price"].isna().sum())
# Out:
# total number of missing values in Ex-Showroom_Price column:  0

# %% [markdown]
# ----

# %% [markdown]
# <div style="background-color:lightgreen; padding:15px; border-radius:8px;">
#   <h2 style="text-align:center; margin:0;">Cleaning "Make", "Model", "Variant", "Body_Type", "Emission_Norm" columns</h2>
# </div>

# %% [markdown]
# -----

# %% [markdown]
# ### 01. Cleaning Make and Model column.

# %% [markdown]
# #### Checking unique values in Make.

# %%
print("unique values of Make column: \n\n",ob_df["Make"].unique())
# Out:
# unique values of Make column:
#
#  <StringArray>
# [            'Tata',           'Datsun',          'Renault',
#     'Maruti Suzuki',          'Hyundai',          'Premier',
#            'Toyota',           'Nissan',       'Volkswagen',
#              'Ford',         'Mahindra',             'Fiat',
#             'Honda',             'Jeep',            'Isuzu',
#             'Skoda',             'Audi',                nan,
#                'Dc',             'Mini',            'Volvo',
#            'Jaguar',              'Bmw',       'Land Rover',
#           'Porsche',            'Lexus',         'Maserati',
#       'Lamborghini',          'Bentley',          'Ferrari',
#      'Aston Martin',          'Bugatti',            'Bajaj',
#              'Icml',            'Force',               'Mg',
#               'Kia', 'Land Rover Rover',       'Mitsubishi',
#   'Maruti Suzuki R']
# Length: 40, dtype: str

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
#
# * There are some **typographical error / duplicate values** in list of **Make Feature.**
#     1. **`Land Rover Rover`** should be **`Land Rover`.**
#
#     2. **`Maruti Suzuki R`** should be **`Maruti Suzuki`.**
#
#     3. **`Dc`** should be **`DC`.**
#
#     4. **`Bmw`** should be **`BMW`.**

# %% [markdown]
# #### Checking the difference of Land Rover Rover in "Make" and "Model" column.

# %%
ob_df[ob_df["Make"]=="Land Rover Rover"][["Make", "Model"]]
# Out:
#                  Make                     Model
# 789  Land Rover Rover              Range Evoque
# 790  Land Rover Rover              Range Evoque
# 791  Land Rover Rover              Range Evoque
# 792  Land Rover Rover              Range Evoque
# 818  Land Rover Rover  Range Evoque Convertible
# 819  Land Rover Rover               Range Velar
# 820  Land Rover Rover               Range Velar
# 827  Land Rover Rover               Range Sport
# 828  Land Rover Rover               Range Sport
# 829  Land Rover Rover               Range Sport
# 830  Land Rover Rover               Range Sport
# 831  Land Rover Rover               Range Sport
# 832  Land Rover Rover               Range Sport
# 833  Land Rover Rover               Range Sport
# 834  Land Rover Rover               Range Sport
# 835  Land Rover Rover               Range Sport
# 836  Land Rover Rover               Range Sport
# 848  Land Rover Rover                     Range
# 849  Land Rover Rover                     Range
# ...

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# * There is **some uncertainty** between **Make** & **Model** Columns.
#     1. In **Make** Column it should be **Land Rover** not **Land Rover Rover**.
#     2. In **Model** Column there should be **Rover** after **Range** in each **model names.**

# %% [markdown]
# #### Replacing Typographical Error

# %%
ob_df["Make"] = ob_df["Make"].replace({"Land Rover Rover" : "Land Rover"})

# %% [markdown]
# #### Checking the difference of Maruti Suzuki R in "Make" and "Model" column.

# %%
mask = ob_df["Model"].str.startswith("Range ", na=False)

ob_df.loc[mask, "Model"] = ob_df.loc[mask, "Model"].apply(
    lambda x: x if x.startswith("Range Rover") else x.replace("Range ", "Range Rover ", 1)
)
ob_df["Model"]= ob_df["Model"].replace({"Range" : "Range Rover"})

# %%
ob_df[ob_df["Make"] == "Maruti Suzuki R"][["Make", "Model"]]
# Out:
#                  Make  Model
# 1173  Maruti Suzuki R  Wagon
# 1174  Maruti Suzuki R  Wagon
# 1175  Maruti Suzuki R  Wagon
# 1176  Maruti Suzuki R  Wagon
# 1177  Maruti Suzuki R  Wagon
# 1178  Maruti Suzuki R  Wagon
# 1179  Maruti Suzuki R  Wagon
# 1180  Maruti Suzuki R  Wagon
# 1181  Maruti Suzuki R  Wagon
# 1182  Maruti Suzuki R  Wagon
# 1183  Maruti Suzuki R  Wagon
# 1184  Maruti Suzuki R  Wagon
# 1185  Maruti Suzuki R  Wagon
# 1186  Maruti Suzuki R  Wagon

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# * There is **some uncertainty** between **Make** and **Model** Columns.
#     1. In **Make** Column it should be **Maruti Suzuki** not **Maruti Suzuki R.**
#     2. In **Model** Column it should be **Wagon R** not only **Wagon.**

# %% [markdown]
# #### Replacing Typographical Error

# %%
ob_df["Make"] = ob_df["Make"].replace({"Maruti Suzuki R" : "Maruti Suzuki"})
ob_df["Model"] = ob_df["Model"].replace({"Wagon" : "Wagon R"})

# %% [markdown]
# #### Missing values in Make column.

# %%
print("Total number of missing values in Make column: ", df["Make"].isna().sum())
# Out:
# Total number of missing values in Make column:  75

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# * For **Filling missing values** we can cross-check the **Make** and **Model** Columns and identy the **car manufacturer** names.

# %%
df[df["Make"].isna()][["Make", "Model"]]
# Out:
#      Make                              Model
# 252   NaN              Mercedes-Benz B-Class
# 253   NaN              Mercedes-Benz B-Class
# 254   NaN              Mercedes-Benz B-Class
# 255   NaN              Mercedes-Benz B-Class
# 256   NaN            Mercedes-Benz Cla-Class
# 257   NaN            Mercedes-Benz Cla-Class
# 258   NaN            Mercedes-Benz Cla-Class
# 303   NaN    Mercedes-Benz E-Class Cabriolet
# 307   NaN                  Mercedes-Benz Gls
# 308   NaN                  Mercedes-Benz Gls
# 309   NaN                  Mercedes-Benz Gls
# 310   NaN                  Mercedes-Benz Gls
# 311   NaN                  Mercedes-Benz Gls
# 322   NaN              Mercedes-Benz S-Class
# 323   NaN              Mercedes-Benz S-Class
# 324   NaN              Mercedes-Benz S-Class
# 328   NaN              Mercedes-Benz G-Class
# 329   NaN              Mercedes-Benz G-Class
# 334   NaN              Mercedes-Benz Maybach
# 335   NaN              Mercedes-Benz Maybach
# ...

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# * We can clearly observe from above output that the **car-manufacture and car model name are combined.**
# * So we can **extract car-manufacture** from the **Model Column** and **fill the missing values in Make Column.**
# * We can extract the following **car-manufactuers:**
#     1. **`Mercedes-Benz`**
#     2. **`Rolls-Royce`**
#     3. **`Datsun`**

# %% [markdown]
# #### Filling Missing Values in "Make" with suitable Car-Manufactuers Names.

# %%
mask = ob_df["Make"].isna()

ob_df.loc[mask, "Model"] = ob_df.loc[mask, "Model"].replace({"Go+": "Datsun Go+"})

parts = ob_df.loc[mask, "Model"].astype(str).str.split(" ", n=1, expand=True)

ob_df.loc[mask, "Make"] = parts[0]

ob_df.loc[mask & parts[1].notna(), "Model"] = parts[1]

# %%
print("total number of missing values in Make column after cleaning: ",ob_df["Make"].isna().sum())
print("total number of missing values in Model column after cleaning: ",ob_df["Model"].isna().sum())
# Out:
# total number of missing values in Make column after cleaning:  0
# total number of missing values in Model column after cleaning:  0

# %% [markdown]
# -----

# %% [markdown]
# ### 02. Cleaning Body_Type column.

# %%
ob_df["Body_Type"].unique()
# Out:
# <StringArray>
# [          'Hatchback',                 'MPV',                 'MUV',
#                  'SUV',               'Sedan',           'Crossover',
#                    nan,               'Coupe',         'Convertible',
#    'Sports, Hatchback',        'Sedan, Coupe',              'Sports',
#       'Crossover, SUV',      'SUV, Crossover',    'Sedan, Crossover',
#  'Sports, Convertible',             'Pick-up',  'Coupe, Convertible']
# Length: 18, dtype: str

# %% [markdown]
# #### Removing Ambiguity Values.

# %%
ob_df["Body_Type"] = ob_df["Body_Type"].str.replace("Crossover, SUV","SUV, Crossover")

# %% [markdown]
# #### Filling missing value in Body_Type.

# %%
ob_df["Body_Type"] = ob_df["Body_Type"].fillna(ob_df["Body_Type"].mode()[0])

# %%
print("total number of missing values in Body_Type column: ", ob_df["Body_Type"].isna().sum())
# Out:
# total number of missing values in Body_Type column:  0

# %% [markdown]
# ----

# %% [markdown]
# ### 03. Cleaning Emisson_Norm column.

# %% [markdown]
# #### Unique values in Emission_Norm.

# %%
ob_df["Emission_Norm"].unique()
# Out:
# <StringArray>
# ['BS IV', 'BS 6', nan, 'BS III', 'BS VI']
# Length: 5, dtype: str

# %% [markdown]
# ### Fetching the "Make" & "Model" where "Emission Norm" is Missing.

# %%
ob_df[ob_df["Emission_Norm"].isna()][["Make", "Model", "Emission_Norm"]]
# Out:
#               Make              Model Emission_Norm
# 240       Mahindra         Alturas G4           NaN
# 243          Honda               Cr-V           NaN
# 347   Aston Martin              Db 11           NaN
# 687       Mahindra           E Verito           NaN
# 688       Mahindra           E Verito           NaN
# 689       Mahindra           E Verito           NaN
# 827     Land Rover  Range Rover Sport           NaN
# 833     Land Rover  Range Rover Sport           NaN
# 1145    Mitsubishi          Outlander           NaN
# 1162        Jaguar             F-Type           NaN
# 1205       Hyundai      Kona Electric           NaN

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# * On searching the above **car details** in **google** I came with below results.
#    1. **Mahindra Alturas G4**, **Honda	Cr-V**, **Aston Martin Db 11**, **Land Rover Range Rover Sport** and **Jaguar F-Type** stores **(BS-VI) emission norms.**
#    2. **Mitsubishi Outlander** stores **(BS-IV) emission norms.**
#    3. **Mahindra E Verito** and **Hyundai	Kona Electric** are **Electric vechiles**. So they don't produce any kind of pollution. So we can fill their **NaN** value with **No Emissions**

# %% [markdown]
# #### Filling missing values in Emission_Norm.

# %%
index_list = ob_df[ob_df["Emission_Norm"].isnull()].index

for index in index_list:
    
    if (ob_df["Make"][index] == "Mahindra") and (ob_df["Model"][index] == "Alturas G4"):
        ob_df.loc[index, "Emission_Norm"] = "BS VI" 

    elif (ob_df["Make"][index] == "Hyundai") and (ob_df["Model"][index] == "Kona Electric"):
        ob_df.loc[index, "Emission_Norm"] = "No Emissions"

    elif ob_df["Make"][index] in ["Honda", "Aston Martin", "Land Rover", "Jaguar"]:
        ob_df.loc[index, "Emission_Norm"] = "BS VI"

    elif (ob_df["Make"][index] == "Mahindra") and (ob_df["Model"][index] == "E Verito"):
        ob_df.loc[index, "Emission_Norm"] = "No Emissions"

    elif (ob_df["Make"][index] == "Mitsubishi") and (ob_df["Model"][index] == "Outlander"):
        ob_df.loc[index, "Emission_Norm"] = "BS IV"

# %% [markdown]
# #### Removing Ambiguity Values.

# %%
ob_df["Emission_Norm"] = ob_df["Emission_Norm"].replace({"BS VI" : "BS 6",
                                                        "BS IV" : "BS 4",
                                                        "BS III" : "BS 3"})

# %% [markdown]
# #### Checking missing values.

# %%
print("Total number of missing values in Emission_Norm column: ", ob_df["Emission_Norm"].isna().sum())
# Out:
# Total number of missing values in Emission_Norm column:  0

# %% [markdown]
# ----

# %% [markdown]
# ### 04. Cleaning Variant column.

# %% [markdown]
# #### Checking Missing values.

# %%
print("Total number of missing values in Variant column: ", ob_df["Variant"].isna().sum())
# Out:
# Total number of missing values in Variant column:  0

# %% [markdown]
# -----

# %% [markdown]
# <div style="background-color:lightgreen; padding:15px; border-radius:8px;">
#   <h2 style="text-align:center; margin:0;">Cleaning "Fuel_Type", "Displacement", "Cylinder_Configuration", "Fuel_System", "Turbocharger", "Power", "Torque" columns</h2>
# </div>
# `

# %% [markdown]
# ----

# %% [markdown]
# ### 01. Cleaning Fuel_Type column.

# %%
ob_df["Fuel_Type"].isna().sum()
# Out:
# np.int64(0)

# %%
ob_df["Fuel_Type"].unique()
# Out:
# <StringArray>
# ['Petrol', 'CNG', 'Diesel', 'CNG + Petrol', 'Hybrid', 'Electric']
# Length: 6, dtype: str

# %% [markdown]
# ----

# %% [markdown]
# ### 02. Cleaning Displacement column.

# %%
ob_df["Displacement"].isna().sum()
# Out:
# np.int64(12)

# %%
ob_df["Displacement"].unique()
# Out:
# <StringArray>
# [ '624 cc',  '799 cc',  '999 cc', '1196 cc',  '998 cc', '1198 cc', '1086 cc',
#  '1199 cc', '1197 cc', '1173 cc',
#  ...
#  '1898 cc', '2360 cc', '1993 cc', '4395 cc', '5000 cc', '5700 cc', '1047 cc',
#  '2200 cc', '2477 cc', '3200 cc']
# Length: 130, dtype: str

# %%
ob_df[ob_df["Displacement"].isna()][["Make", "Model", "Displacement", "Fuel_Type"]]
# Out:
#                Make                Model Displacement Fuel_Type
# 615        Mahindra             E2O Plus          NaN  Electric
# 616        Mahindra             E2O Plus          NaN  Electric
# 617            Tata             Tigor Ev          NaN  Electric
# 618            Tata             Tigor Ev          NaN  Electric
# 619            Tata             Tigor Ev          NaN  Electric
# 745              Mg                Zs Ev          NaN  Electric
# 746              Mg                Zs Ev          NaN  Electric
# 862   Mercedes-Benz  Amg Gt 4-Door Coupe          NaN    Petrol
# 1006           Tata             Nexon Ev          NaN  Electric
# 1007           Tata             Nexon Ev          NaN  Electric
# 1008           Tata             Nexon Ev          NaN  Electric
# 1205        Hyundai        Kona Electric          NaN  Electric

# %%
mask= ob_df["Fuel_Type"]== "Electric"

ob_df.loc[mask, "Displacement"] = ob_df.loc[mask, "Displacement"].fillna("0 cc")

ob_df.loc[mask & ~(ob_df["Displacement"].astype(str).str.strip().str.startswith("0")), "Displacement"] = "0 cc"

# %%
mask= ob_df["Fuel_Type"]== "Petrol"

ob_df.loc[mask, "Displacement"] = ob_df.loc[mask, "Displacement"].fillna("3982 cc")

# %%
print("Total number of missing value in Displacement column: ",ob_df["Displacement"].isna().sum())
# Out:
# Total number of missing value in Displacement column:  0

# %%
mask = ob_df["Displacement"].astype(str).str.strip().str.split(" ").str[0]
ob_df["Displacement"] = mask

# %%
ob_df["Displacement"] = ob_df["Displacement"].astype(int)

# %%
ob_df.rename(columns= {"Displacement" : "Displacement (cc)"}, inplace = True)

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# In some places, the Displacement column contains wrong or missing values.
# So, using the **Fuel_Type column**, we:
#
# * Fill missing displacement values for **Electric cars** with "0 cc", because electric vehicles do not have engine displacement.
#
# * Correct incorrect displacement values for Electric cars (like "72 cc", "1197 cc", etc.) and replace them with "0 cc".
#
# * For **other cars**, after doing some online research, we filled the missing displacement values with the most suitable displacement according to the car’s actual specifications.
#
# * After completing the cleaning process, we converted the Displacement column to integer type for machine learning prediction.

# %% [markdown]
# -----

# %% [markdown]
# ### 03. Cleaning Cylinder_Configuration column.

# %% [markdown]
# #### Checking missing values.

# %%
ob_df["Cylinder_Configuration"].isna().sum()
# Out:
# np.int64(13)

# %% [markdown]
# #### checking unique values.

# %%
ob_df["Cylinder_Configuration"].unique()
# Out:
# <StringArray>
# ['In-line', 'V', 'Flat', 'W', nan]
# Length: 5, dtype: str

# %%
ob_df[ob_df["Cylinder_Configuration"].isna()][["Make", "Model", "Cylinder_Configuration", "Fuel_Type"]]
# Out:
#             Make              Model Cylinder_Configuration Fuel_Type
# 388      Hyundai    Grand I10 Prime                    NaN    Diesel
# 389      Hyundai    Grand I10 Prime                    NaN    Diesel
# 617         Tata           Tigor Ev                    NaN  Electric
# 618         Tata           Tigor Ev                    NaN  Electric
# 619         Tata           Tigor Ev                    NaN  Electric
# 687     Mahindra           E Verito                    NaN  Electric
# 688     Mahindra           E Verito                    NaN  Electric
# 689     Mahindra           E Verito                    NaN  Electric
# 833   Land Rover  Range Rover Sport                    NaN    Petrol
# 851   Land Rover        Range Rover                    NaN    Petrol
# 1145  Mitsubishi          Outlander                    NaN    Petrol
# 1162      Jaguar             F-Type                    NaN    Petrol
# 1205     Hyundai      Kona Electric                    NaN  Electric

# %% [markdown]
# #### Filling missing values.

# %%
# Clean columns first
ob_df["Make"] = ob_df["Make"].astype(str).str.strip()
ob_df["Model"] = ob_df["Model"].astype(str).str.strip()
ob_df["Fuel_Type"] = ob_df["Fuel_Type"].astype(str).str.strip()

# Convert fake missing values to real NaN
ob_df["Cylinder_Configuration"] = ob_df["Cylinder_Configuration"].replace(
    ["", " ", "  ", "nan", "NaN", "None"], np.nan
)

# 1) Electric cars => Not Applicable
mask = ob_df["Fuel_Type"].str.lower().eq("electric")
ob_df.loc[mask, "Cylinder_Configuration"] = ob_df.loc[mask, "Cylinder_Configuration"].fillna("Not Applicable")

# 2) Hyundai Grand I10 Prime => Inline
mask1 = (ob_df["Make"].str.lower().eq("hyundai")) & (ob_df["Model"].str.lower().eq("grand I10 prime") | (ob_df["Fuel_Type"]=="Diesel"))
ob_df.loc[mask1, "Cylinder_Configuration"] = ob_df.loc[mask1, "Cylinder_Configuration"].fillna("In-line")

# 3) Mitsubishi Outlander => Inline
mask2 = (ob_df["Make"].str.lower().eq("mitsubishi")) & (ob_df["Model"].str.lower().eq("outlander"))
ob_df.loc[mask2, "Cylinder_Configuration"] = ob_df.loc[mask2, "Cylinder_Configuration"].fillna("In-line")

# 4) Jaguar F-Type => V
mask3 = (ob_df["Make"].str.lower().eq("jaguar")) & (ob_df["Model"].str.lower().eq("f-type"))
ob_df.loc[mask3, "Cylinder_Configuration"] = ob_df.loc[mask3, "Cylinder_Configuration"].fillna("V")

# 5) Land Rover Range Rover Sport / Range Rover => Inline
mask4 = (ob_df["Make"].eq("Land Rover")) & (
    ob_df["Model"].isin(["Range Rover Sport", "Range Rover"])
)
ob_df.loc[mask4, "Cylinder_Configuration"] = ob_df.loc[mask4, "Cylinder_Configuration"].fillna("In-line")

# %%
ob_df["Cylinder_Configuration"] = ob_df["Cylinder_Configuration"].str.replace("Inline" , "In-line")

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# After doing some online research, we filled the **Cylinder_Configuration** column with suitable values:
#
# * Electric cars → Not Applicable
#
# * Hyundai Grand i10 Prime → In-line
#
# * Mitsubishi Outlander → In-line
#
# * Land Rover Range Rover Sport and Land Rover Range Rover → In-line
#
# * Jaguar F-Type → V

# %%
ob_df["Cylinder_Configuration"]= ob_df["Cylinder_Configuration"].astype("object")

# %% [markdown]
# #### Checking missing values

# %%
print("Total number of missing values in Cylinder_Configuration column: ", ob_df["Cylinder_Configuration"].isna().sum())
# Out:
# Total number of missing values in Cylinder_Configuration column:  0

# %% [markdown]
# ----

# %% [markdown]
# ### 04. Cleaning Fuel_System column.

# %%
print("Total number of missing values in Fuel_System column: ", ob_df["Fuel_System"].isna().sum())
# Out:
# Total number of missing values in Fuel_System column:  8

# %%
print(ob_df["Fuel_System"].unique())
# Out:
# <StringArray>
# ['Injection', 'PGM - Fi', nan]
# Length: 3, dtype: str

# %%
ob_df[ob_df["Fuel_System"].isna()][["Make", "Model", "Fuel_Type", "Fuel_System"]]
# Out:
#             Make              Model Fuel_Type Fuel_System
# 687     Mahindra           E Verito  Electric         NaN
# 688     Mahindra           E Verito  Electric         NaN
# 689     Mahindra           E Verito  Electric         NaN
# 827   Land Rover  Range Rover Sport    Petrol         NaN
# 833   Land Rover  Range Rover Sport    Petrol         NaN
# 1145  Mitsubishi          Outlander    Petrol         NaN
# 1162      Jaguar             F-Type    Petrol         NaN
# 1205     Hyundai      Kona Electric  Electric         NaN

# %% [markdown]
# #### Filling missing values

# %%
mask = (ob_df["Fuel_System"].isna()) & (ob_df["Fuel_Type"]==("Petrol"))
ob_df.loc[mask, "Fuel_System"] = "Injection"

mask1= (ob_df["Fuel_System"].isna()) & (ob_df["Fuel_Type"]== "Electric")
ob_df.loc[mask1, "Fuel_System"] = "Not Applicable"

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# * Based on online research, Land Rover, Mitsubishi, and Jaguar vehicles have Injection as the fuel system.
# * For electric vehicles (EVs), the fuel system should be Not Applicable since they do not use fuel injection.

# %% [markdown]
# #### Checking missing values

# %%
print("Total number of missing value in Fuel_System column: ",ob_df["Fuel_System"].isna().sum())
# Out:
# Total number of missing value in Fuel_System column:  0

# %% [markdown]
# -----

# %% [markdown]
# ### 05. Cleaning Turbocharger column.

# %% [markdown]
# #### Displaying unique values

# %%
ob_df["Turbocharger"].unique()
# Out:
# <StringArray>
# [nan, 'Yes']
# Length: 2, dtype: str

# %% [markdown]
# #### Checking missing values

# %%
print("Total number of missing value: ", ob_df["Turbocharger"].isna().sum())
# Out:
# Total number of missing value:  618

# %%
ob_df[ob_df["Turbocharger"].isna()][["Fuel_Type", "Turbocharger"]]
# Out:
#          Fuel_Type Turbocharger
# 0           Petrol          NaN
# 1           Petrol          NaN
# 2              CNG          NaN
# 3           Petrol          NaN
# 4           Petrol          NaN
# 5           Petrol          NaN
# 6           Petrol          NaN
# 7           Petrol          NaN
# 8           Petrol          NaN
# 9           Petrol          NaN
# 10          Petrol          NaN
# 11          Petrol          NaN
# 12          Petrol          NaN
# 13          Petrol          NaN
# 14          Petrol          NaN
# 15          Petrol          NaN
# 16          Petrol          NaN
# 17          Petrol          NaN
# 18          Petrol          NaN
# 19          Petrol          NaN
# 20          Petrol          NaN
# 21          Petrol          NaN
# 22          Petrol          NaN
# 23          Petrol          NaN
# 24          Petrol          NaN
# 25          Petrol          NaN
# 26          Petrol          NaN
# 27             CNG          NaN
# ...

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
#  Based on **online research**
# * **vehicles** running on **Petrol**, **CNG**, **Diesel**, or **CNG + Petrol** may use a **turbocharger**.
# * However, **electric vehicles** do not use turbochargers since they do not have **combustion engines** or **exhaust gases**.
# * and For **hybrid vehicles**, we need to conduct additional **online research** to determine whether a turbocharger is applicable.

# %% [markdown]
# #### Filling missing values

# %%
mask = (ob_df["Turbocharger"].isna()) & (ob_df["Fuel_Type"].str.strip().str.lower().isin(["petrol", "cng", "diesel", "cng + petrol"]))

ob_df.loc[mask, "Turbocharger"] = "Yes"

mask2 = (ob_df["Turbocharger"].isna()) & (ob_df["Fuel_Type"].str.strip().str.lower().isin(["electric"]))

ob_df.loc[mask2, "Turbocharger"] = "No"

# %%
ob_df[ob_df["Turbocharger"].isna()][["Make", "Model", "Fuel_Type", "Turbocharger"]]
# Out:
#         Make          Model Fuel_Type Turbocharger
# 333    Lexus        Lc 500H    Hybrid          NaN
# 824    Volvo           Xc90    Hybrid          NaN
# 825    Volvo           Xc90    Hybrid          NaN
# 1001      Mg         Hector    Hybrid          NaN
# 1002      Mg         Hector    Hybrid          NaN
# 1003      Mg         Hector    Hybrid          NaN
# 1039  Toyota          Prius    Hybrid          NaN
# 1040   Lexus             Es    Hybrid          NaN
# 1152   Honda  Accord Hybrid    Hybrid          NaN
# 1206  Toyota          Camry    Hybrid          NaN
# 1216   Lexus        Ls 500H    Hybrid          NaN
# 1217   Lexus        Ls 500H    Hybrid          NaN
# 1218   Lexus        Ls 500H    Hybrid          NaN

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# Based on **online research**
# ____
# * **Hybrid Vehicles With Turbocharger**
# ____
#
# The following hybrid vehicles are expected to have a turbocharger:
#
# 1. Volvo XC90 (Hybrid) – Turbocharger applicable
#
# 2. MG Hector (Hybrid category in dataset) – Turbocharger applicable
#
# 3. Lexus LS 500h – Turbocharger applicable
#
# -----
# * **Hybrid Vehicles Without Turbocharger**
# _____
#
# The following hybrid vehicles are not expected to have a turbocharger:
#
# 1. Lexus LC 500h – Turbocharger not applicable
#
# 2. Toyota Prius – Turbocharger not applicable
#
# 3. Lexus ES (Hybrid) – Turbocharger not applicable
#
# 4. Honda Accord Hybrid – Turbocharger not applicable
#
# 5. Toyota Camry (Hybrid) – Turbocharger not applicable

# %%
mask1 = (
    (ob_df["Turbocharger"].isna())
    & (
        (
            (ob_df["Make"].str.strip().str.lower() == "volvo")
            & (ob_df["Model"].str.strip().str.lower() == "xc90")
        )
        | (
            (ob_df["Make"].str.strip().str.lower() == "mg")
            & (ob_df["Model"].str.strip().str.lower() == "hector")
        )
        | (
            (ob_df["Make"].str.strip().str.lower() == "lexus")
            & (ob_df["Model"].str.strip().str.lower() == "ls 500h")
        )
    )
)

ob_df.loc[mask1, "Turbocharger"] = "Yes"

mask2 = (
    (ob_df["Turbocharger"].isna())
    & (
        (
            (ob_df["Make"].str.strip().str.lower() == "lexus")
            & (ob_df["Model"].str.strip().str.lower() == "lc 500h")
        )
        | (
            (ob_df["Make"].str.strip().str.lower() == "toyota")
            & (ob_df["Model"].str.strip().str.lower() == "prius")
        )
        | (
            (ob_df["Make"].str.strip().str.lower() == "lexus")
            & (ob_df["Model"].str.strip().str.lower() == "es")
        )
        | (
            (ob_df["Make"].str.strip().str.lower() == "honda")
            & (ob_df["Model"].str.strip().str.lower() == "accord hybrid")
        )
        | (
            (ob_df["Make"].str.strip().str.lower() == "toyota")
            & (ob_df["Model"].str.strip().str.lower() == "camry")
        )
    )
)

ob_df.loc[mask2, "Turbocharger"] = "No"

# %% [markdown]
# #### Checking missing values

# %%
print("Total number of missing value: ", ob_df["Turbocharger"].isna().sum())
# Out:
# Total number of missing value:  0

# %% [markdown]
# ----

# %% [markdown]
# ### 06. Cleaning Power column

# %% [markdown]
# #### Displaying sample data

# %%
ob_df["Power"].sample(5).to_frame()
# Out:
#               Power
# 187   100PS@3750RPM
# 87     80PS@5600rpm
# 1196  106PS@5600rpm
# 1075   72PS@4000rpm
# 1135  128ps@4000rpm

# %% [markdown]
# #### Checking missing values

# %%
print("Total number of missing values:", ob_df["Power"].isna().sum())
# Out:
# Total number of missing values: 0

# %% [markdown]
# #### Displaying unique values.

# %%
ob_df["Power"].unique()
# Out:
# <StringArray>
# [      '38PS@5500rpm',       '54PS@5678rpm',       '68PS@5500rpm',
#        '73PS@6000rpm',       '74PS@6000RPM',       '62PS@6000rpm',
#        '68PS@6000rpm',       '68PS@6200rpm',       '59PS@6000rpm',
#        '68PS@5000rpm',
#  ...
#       '394PS@3750rpm',      '107PS@6000rpm', '197PS@5500-6100rpm',
#       '194PS@3800rpm',    '340PS@5300-6400',    '550PS@5750-6000',
#       '178PS@4000rpm',      '507PS@6000rpm',      '616PS@6100rpm',
#       '202ps@3800rpm']
# Length: 372, dtype: str

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# * There are **No missing values** present in **Power Feature.**
# * From the Unique Values we can observe **different unit of measures for power values.**
# * So its **important to convert all the units to a single unit**.
# * Hence we can **convert all the power values** to a single unit which can be **HP(Horse Power).**
# * **Note:**
#     1. **1 PS** is roughly equivalent to **0.98632 horsepower (hp).**
#     2. **1 BHP** is equivalent to **1.01387 horsepower (hp).**
#     3. **1 KW** is equivalent to approximately **1.34 horsepower (hp).**
#     4. Some of the value are having **Nm units of measurement** but in relaity they are **units for torque values.**

# %%
mask = ob_df["Power"].str.contains("nm", case=False, na=False)

index = ob_df.index[mask].tolist()
ob_df.loc[index, ["Power", "Torque"]]
# Out:
#                    Power           Torque
# 356  1600Nm@2000-6000rpm  1479bhp@6700rpm

# %%
ob_df.loc[index, ["Power", "Torque"]] = ob_df.loc[index, ["Torque", "Power"]].values

# %% [markdown]
# #### converting all the power values in to single unit(HP unit)

# %%
new_power = []      ##To store all the converted power values...

for i in ob_df["Power"]:
    power_value = i.split("@")[0].replace(" ","").lower() 

    if "ps" in power_value:
        value1 = round((float(power_value.replace("ps",""))*0.98632),2)
        new_power.append(value1)
    
    elif "bhp" in power_value:
        value2 = round((float(power_value.replace("bhp",""))*1.01387),2)
        new_power.append(value2)
    
    elif "hp" in power_value:
        value3 = float(power_value.replace("hp",""))
        new_power.append(value3)
    
    elif "kw" in power_value:
        value4 = round((float(power_value.replace("kw",""))*1.34),2)
        new_power.append(value4)
    else:
        new_power.append(power_value)

# %% [markdown]
# #### Assigning new power value to the power column

# %%
ob_df["Power"] = new_power

# %% [markdown]
# #### Converting data-type to float

# %%
ob_df["Power"]= ob_df["Power"].astype(float)

# %% [markdown]
# #### Assiging new Name to the "Power" Column.

# %%
ob_df.rename(columns={"Power":"Power (HP)"},inplace=True)

# %% [markdown]
# ### 07. Cleaning Torque column

# %% [markdown]
# #### Displaying sample values

# %%
ob_df["Torque"].sample(5).to_frame()
# Out:
#                   Torque
# 1134       151Nm@4850rpm
# 903        190Nm@2000rpm
# 747   440Nm@1750-2750rpm
# 710        245Nm@4000rpm
# 610   250Nm@1500-2500rpm

# %% [markdown]
# #### Missing values of Torque column

# %%
print("Total number of missing values of Torque column", ob_df["Torque"].isna().sum())
# Out:
# Total number of missing values of Torque column 2

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# * we can fill the missing value after some online research.

# %% [markdown]
# #### Displayin unique values of Torque column

# %%
ob_df["Torque"].unique()
# Out:
# <StringArray>
# [      '51Nm@4000rpm',       '72Nm@4386rpm',       '91Nm@4250RPM',
#       '101Nm@3000rpm',       '85Nm@3000rpm',       '90Nm@3500rpm',
#        '78Nm@3500rpm',      '104Nm@4000rpm',    '99.04nm@4500RPM',
#     '10.1kgm@4500RPM',
#  ...
#  '250Nm@1500-3500rpm', '320Nm@1650-4000rpm',    '450Nm@1340-5300',
#     '770Nm@2000-4500',      '400Nm@2000rpm', '350Nm@1800-3500rpm',
#  '400Nm@2000-2500rpm',      '660NM@1700rpm', '800Nm@1600-6100rpm',
#       '441Nm@2000rpm']
# Length: 342, dtype: str

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# * Based on the **unique values**, all **Torque measurements** are recorded in the **different unit (Nm, kgm)**.
# *So its **important to convert all the units to a single unit**.
# * Hence we can **convert all the Torque values** to a single unit which can be **Nm(Newton-meter).**
# * **Note:**
#     1. **1 kgm** is roughly equivalent to  **9.81 Newton-meter(Nm)**.
#     2. Some of the value are having **Hp units of measurement** but in relaity they are **units for Power values.**

# %%
ob_df[
    ob_df["Torque"]
    .astype(str)
    .str.lower()
    .str.startswith("320hp")
]
# Out:
#      Ex-Showroom_Price Make        Model     Variant            Body_Type  \
# 807            6490000  Bmw  Z4 Roadster  Sdrive 20I  Sports, Convertible
#
#     Emission_Norm Fuel_Type  Displacement (cc) Cylinder_Configuration  \
# 807          BS 6    Petrol               1998                In-line
#
#     Fuel_System Turbocharger  Power (HP)              Torque   Length  \
# 807   Injection          Yes       197.0  320hp@1450-2000rpm  4324 mm
#
#        Width   Height Wheelbase Kerb_Weight Ground_Clearance  \
# 807  2024 mm  1304 mm   2470 mm     1495 kg              NaN
#
#                  Drivetrain Gears          Front_Suspension  \
# 807  RWD (Rear Wheel Drive)     8  Adaptive Dynamics system
#
#               Rear_Suspension     Front_Brakes      Rear_Brakes  \
# 807  Adaptive Dynamics system  Ventilated Disc  Ventilated Disc
#
#     ARAI_Certified_Mileage City_Mileage Highway_Mileage  \
# 807           7.6 km/litre          NaN             NaN
#
# ...

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# * After some online research, the torque of the BMW Z4 Roadster is 320 Nm.

# %% [markdown]
# #### Filling missing values and extracting numerical values.

# %%
ob_df.loc[807, "Torque"] = "320nm"

# %%
def convert_torque(x):
    if pd.isna(x):
        return np.nan

    x = str(x).lower()
    x = " ".join(x.split())
    x = x.replace(" ", "")

    if "kgm" in x:
        return float(x.split("kgm")[0]) * 9.81
    elif "nm" in x:
        return float(x.split("nm")[0])
    elif "@" in x:
        return float(x.split("@")[0])
    else:
        return float(x)  

ob_df["Torque"] = ob_df["Torque"].apply(convert_torque)

# %%
ob_df[ob_df["Torque"].isna()][["Make", "Model", "Torque"]]
# Out:
#           Make              Model  Torque
# 536   Mahindra  Bolero Power Plus     NaN
# 1158       Bmw           6-Series     NaN

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# * After some **online research**, the **Torque values** for these cars were identified as follows:
#
# 1. **Mahindra Bolero Power Plus**: **195 Nm**
#
# 2. **BMW 6-Series**: **630 Nm**

# %%
mask1 = (ob_df["Make"] == "Mahindra") & (ob_df["Model"] == "Bolero Power Plus")
ob_df.loc[mask1, "Torque"] = ob_df.loc[mask1, "Torque"].fillna(value = 195)

mask2 = (ob_df["Make"] == "Bmw") & (ob_df["Model"] == "6-Series")
ob_df.loc[mask2, "Torque"] = ob_df.loc[mask2, "Torque"].fillna(value = 630)

ob_df["Torque"] = ob_df["Torque"].apply(lambda x: str(x).strip())

# %% [markdown]
# #### Changing the Data-Type to Float

# %%
ob_df["Torque"] = ob_df["Torque"].astype(float)

# %% [markdown]
# #### Changing column name

# %%
ob_df.rename(columns = {"Torque" : "Torque (Nm)"}, inplace = True)

# %% [markdown]
# -----

# %% [markdown]
# <div style="background-color:lightgreen; padding:15px; border-radius:8px;">
#   <h2 style="text-align:center; margin:0;">Cleaning     "Length",
#     "Width",
#     "Height",
#     "Wheelbase",
#     "Kerb_Weight",
#     "Ground_Clearance" columns</h2>
# </div>
# `

# %% [markdown]
# ### 01. Cleaning Lenght, Width, Height, Wheelbase column

# %% [markdown]
# #### Displaying sample values

# %%
cols = ["Length", "Width", "Height", "Wheelbase", "Ground_Clearance"]

ob_df[cols].sample(5)
# Out:
#        Length    Width   Height Wheelbase Ground_Clearance
# 415   3700 mm  1735 mm  1655 mm   2385 mm           170 mm
# 1029  4299 mm  1822 mm  1557 mm   2670 mm              NaN
# 541   3995 mm  1790 mm  1640 mm   2500 mm           198 mm
# 1231  4425 mm  1730 mm  1495 mm   2550 mm           152 mm
# 1072  3995 mm  1660 mm  1520 mm   2425 mm           165 mm

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# * All the features are having **same unit of measure** which is **mm.**
# * Hence we can simply **extract numerical values** and **convert its data-type.**

# %%
cols = ["Length", "Width", "Height", "Wheelbase", "Ground_Clearance"]

ob_df[cols] = ob_df[cols].apply(lambda x: x.astype(str).str.split().str[0].str.replace(".","", regex = False).replace("nan", np.nan))

# %% [markdown]
# #### Checking missing values

# %%
ob_df[cols].isna().sum().to_frame(name= "Missing values")
# Out:
#                   Missing values
# Length                         0
# Width                         12
# Height                         1
# Wheelbase                     20
# Ground_Clearance             289

# %%
ob_df[ob_df["Height"].isna()][["Make", "Model", "Height", "Width", "Length", "Wheelbase"]]
# Out:
#      Make Model Height Width Length Wheelbase
# 314  Audi   Rs5    NaN   NaN   4649       NaN

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# * On **searching** this **car detial on google** I found the following result:-
#     1. **Height = 1387 mm**
#     2. **Width  = 1866 mm**
#     3. **Wheelbase = 2826 mm**

# %%
ob_df.loc[314, "Height"] = "1387.0"
ob_df.loc[314, "Width"] = "1866.0"
ob_df.loc[314, "Wheelbase"] = "2826.0"

# %%
ob_df[ob_df["Width"].isna()][["Make", "Model"]+cols]
# Out:
#      Make    Model Length Width Height Wheelbase Ground_Clearance
# 440  Icml  Extreme   4440   NaN   1885      2541              170
# 441  Icml  Extreme   4440   NaN   1885      2541              170
# 442  Icml  Extreme   4440   NaN   1885      2541              170
# 443  Icml  Extreme   4440   NaN   1885      2541              170
# 444  Icml  Extreme   4440   NaN   1885      2541              170
# 445  Icml  Extreme   4440   NaN   1885      2541              170
# 446  Icml  Extreme   4440   NaN   1885      2541              170
# 447  Icml  Extreme   4440   NaN   1885      2541              170
# 448  Icml  Extreme   4440   NaN   1885      2541              170
# 449  Icml  Extreme   4440   NaN   1885      2541              170
# 450  Icml  Extreme   4440   NaN   1885      2541              170

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# * On **searching** this **car detial on google** I found that the **width** of **Icml Extreme** is **1645 mm.**

# %%
ob_df["Width"] = ob_df["Width"].fillna("1645.0")

# %%
ob_df[ob_df["Wheelbase"].isna()][["Make", "Model"]+cols]
# Out:
#                Make          Model Length Width Height Wheelbase  \
# 267            Mini  Cooper 5 Door   3982  1727   1425       NaN
# 268            Mini    Convertible   3850  1727   1415       NaN
# 771            Mini  Cooper 3 Door   3821  1727   1414       NaN
# 772            Mini  Cooper 3 Door   3850  1727   1414       NaN
# 1046           Audi   A5 Cabriolet   4733  1843   1386       NaN
# 1049  Mercedes-Benz            Cls   4988  1890   1435       NaN
# 1173  Maruti Suzuki        Wagon R   3655  1620   1675       NaN
# 1174  Maruti Suzuki        Wagon R   3655  1620   1675       NaN
# 1175  Maruti Suzuki        Wagon R   3655  1675   1620       NaN
# 1176  Maruti Suzuki        Wagon R   3655  1620   1675       NaN
# 1178  Maruti Suzuki        Wagon R   3655  1620   1675       NaN
# 1179  Maruti Suzuki        Wagon R   3655  1620   1675       NaN
# 1180  Maruti Suzuki        Wagon R   3655  1620   1675       NaN
# ...

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# After doing some **online research**, I found the following **wheelbase measurements** for these cars:
#
# * Maruti Suzuki Wagon R — 2435 mm
#
# * Audi A5 — 2826 mm
#
# * Audi A5 Cabriolet — 2765 mm
#
# * Mini Cooper 3 Door — 2495 mm
#
# * Mini Convertible — 2495 mm
#
# * Mini Cooper 5 Door — 2567 mm
#
# * Mercedes-Benz Cls — 2874 mm

# %%
wheelbase_map = {
    ("Maruti Suzuki", "Wagon R"): 2435,
    ("Audi", "A5"): 2826,
    ("Audi", "A5 Cabriolet"): 2765,
    ("Mini", "Cooper 3 Door"): 2495,
    ("Mini", "Convertible"): 2495,
    ("Mini", "Cooper 5 Door"): 2567,
    ("Mercedes-Benz", "Cls"): 2874
}

mask = ob_df["Wheelbase"].isna()

ob_df.loc[mask, "Wheelbase"] = ob_df.loc[mask, ["Make", "Model"]].apply(
    lambda r: wheelbase_map.get((r["Make"], r["Model"]), np.nan),
    axis=1
)

# %% [markdown]
# ### 02. Cleaning Ground_Clearance column

# %%
print("Total number of missing values: ", ob_df["Ground_Clearance"].isna().sum())
# Out:
# Total number of missing values:  289

# %%
ob_df[ob_df["Ground_Clearance"].isna()][["Make", "Model"]+cols].sample(10)
# Out:
#               Make              Model Length Width Height Wheelbase  \
# 875        Ferrari         Gtc4 Lusso   4922  1980   1383      2990
# 140        Hyundai               Aura   3995  1680   1520      2450
# 765         Toyota           Fortuner   4795  1855   1835      2745
# 371  Maruti Suzuki           S-Presso   3565  1520   1549      2380
# 771           Mini      Cooper 3 Door   3821  1727   1414      2495
# 656       Mahindra            Scorpio   4456  1820   1995      2680
# 726           Jeep            Compass   4395  1818   1640      2636
# 340  Mercedes-Benz  S-Class Cabriolet   5027  1899   1417      2945
# 51         Hyundai             Santro   3610  1645   1560      2400
# 351    Rolls-Royce             Wraith   5269  1947   1507      3112
#
#     Ground_Clearance
# 875              NaN
# 140              NaN
# 765              NaN
# 371              NaN
# 771              NaN
# 656              NaN
# 726              NaN
# 340              NaN
# ...

# %% [markdown]
# #### Converting the column’s data type to a float

# %%
ob_df[cols] = ob_df[cols].astype(float)

# %% [markdown]
# #### Filling missing value with median

# %%
ob_df["Ground_Clearance"] = ob_df["Ground_Clearance"].fillna(
    ob_df.groupby(["Make", "Model"])["Ground_Clearance"].transform("median")
)

ob_df["Ground_Clearance"] = ob_df["Ground_Clearance"].fillna(
    ob_df.groupby("Make")["Ground_Clearance"].transform("median")
)

ob_df["Ground_Clearance"] = ob_df["Ground_Clearance"].fillna(ob_df["Ground_Clearance"].median())

# %% [markdown]
# #### Checking missing values

# %%
ob_df[cols].isna().sum().to_frame(name= "Missing values")
# Out:
#                   Missing values
# Length                         0
# Width                          0
# Height                         0
# Wheelbase                      0
# Ground_Clearance               0

# %% [markdown]
# ----

# %% [markdown]
# ### 03. Cleaning Kerb_Weight column

# %% [markdown]
# #### Displaying some sample values of Kerb_Weight.

# %%
ob_df[["Kerb_Weight"]].sample(5)
# Out:
#      Kerb_Weight
# 1213         NaN
# 1251         NaN
# 974          NaN
# 1101     1105 kg
# 776          NaN

# %% [markdown]
# #### Missing values in Kerb_Weight column

# %%
print("Total number of missing value: ", ob_df["Kerb_Weight"].isna().sum())
# Out:
# Total number of missing value:  365

# %% [markdown]
# #### Displaying unique values of Kerb_Weight column

# %%
ob_df["Kerb_Weight"].unique()
# Out:
# <StringArray>
# [ '660 kg',  '725 kg',  '710 kg',       nan,  '669 kg',  '920 kg',  '940 kg',
#   '928 kg', '1050 kg', '1030 kg',
#  ...
#  '1376 kg', '2040 kg', '2417 kg', '2475 kg', '1063 kg', '1061 kg', '1084 kg',
#  '1147 kg', '1107 kg', '2335 kg']
# Length: 337, dtype: str

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# * In **the column** we can observe that the **numerical values are attached with their respective unit of measure.**
# * So we can simply **extract numerical values** and **convert its data-type.**

# %% [markdown]
# #### Extracting numerical data from Kerb_Weight column

# %%
ob_df["Kerb_Weight"] = ob_df["Kerb_Weight"].apply(lambda x: str(x).split(" ")[0].split("-")[0]).astype(float)

# %% [markdown]
# #### Filling missing values with median

# %%
median = ob_df["Kerb_Weight"].median()

ob_df["Kerb_Weight"] = ob_df["Kerb_Weight"].fillna(value = median)

# %% [markdown]
# #### Missing values in Kerb_Weight column

# %%
print("Total number of missing value: ", ob_df["Kerb_Weight"].isna().sum())
# Out:
# Total number of missing value:  0

# %% [markdown]
# ------

# %% [markdown]
# <div style="background-color:lightgreen; padding:15px; border-radius:8px;">
#   <h2 style="text-align:center; margin:0;">Cleaning     "ARAI_Certified_Mileage",
#     "City_Mileage",
#     "Highway_Mileage" columns</h2>
# </div>
# `

# %% [markdown]
# ### 01. Cleaning "ARAI_Certified_Mileage", "City_Mileage","Highway_Mileage" columns.

# %% [markdown]
# #### Displaying sample values

# %%
ob_df[["ARAI_Certified_Mileage",
    "City_Mileage",
    "Highway_Mileage"]].sample(5)
# Out:
#      ARAI_Certified_Mileage   City_Mileage Highway_Mileage
# 1222          20.5 km/litre  21,2 km/litre             NaN
# 201          16.78 km/litre  13,6 km/litre   16.3 km/litre
# 101          18.97 km/litre            NaN             NaN
# 508           17.6 km/litre            NaN             NaN
# 531           15.7 km/litre  11,3 km/litre   15.7 km/litre

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# * All the features are having **same unit of measure** which is **km/litre.**
# * Hence we can simply **extract numerical values** and **convert its data-type.**

# %% [markdown]
# #### Displaying missing values

# %%
ob_df[["ARAI_Certified_Mileage",
    "City_Mileage",
    "Highway_Mileage"]].isna().sum().to_frame(name= "Missing values")
# Out:
#                         Missing values
# ARAI_Certified_Mileage             114
# City_Mileage                       554
# Highway_Mileage                    792

# %%
ob_df[
    ob_df["ARAI_Certified_Mileage"]
    .astype(str)
    .str.strip()
    .str.lower()
    .str.endswith("kmpl")
].index
# Out:
# Index([], dtype='int64')

# %% [markdown]
# #### Displaying unique values of ARAI_Certified_Mileage column

# %%
ob_df["ARAI_Certified_Mileage"].unique()
# Out:
# <StringArray>
# [ '23.6 km/litre',              nan,  '21.9 km/litre', '25.17 km/litre',
#   '22.5 km/litre',    '23 km/litre', '23.01 km/litre', '24.04 km/litre',
#     '15 km/litre', '24.07 km/litre',
#  ...
#   '21.2 km/litre', '13.51 km/litre', '18.18 km/litre', '10.77 km/litre',
#      '4 km/litre',  '17.4 km/litre',  '25.6 km/litre',  '25.1 km/litre',
#   '22.6 km/litre', '11.56 km/litre']
# Length: 282, dtype: str

# %% [markdown]
# #### Extracting numerical data from ARAI_Certified_Mileage column

# %%
ob_df["ARAI_Certified_Mileage"] = (
    ob_df["ARAI_Certified_Mileage"]
    .astype(str)
    .str.lower()
    .str.replace("kmpl", "", regex=False)
    .str.replace("km/litre", "", regex=False)
    .str.replace("km/l", "", regex=False)
    .str.strip()
)

# %%
def mileage_to_float(x):
    if pd.isna(x):
        return np.nan
    
    x = str(x)  # convert everything to string safely
    
    if "-" in x:
        a, b = x.split("-")
        return (float(a) + float(b)) / 2
    
    try:
        return float(x)
    except:
        return np.nan

ob_df["ARAI_Certified_Mileage"] = ob_df["ARAI_Certified_Mileage"].apply(mileage_to_float)

# %% [markdown]
# #### Filling missing values

# %%
ob_df["ARAI_Certified_Mileage"] = ob_df["ARAI_Certified_Mileage"].fillna(value= ob_df["ARAI_Certified_Mileage"].median())

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# * We are filling the missing values using the column’s median.

# %% [markdown]
# #### Missing values in ARAI_Certified_Mileage column

# %%
print("Total number of missing value: ", ob_df["ARAI_Certified_Mileage"].isna().sum())
# Out:
# Total number of missing value:  0

# %% [markdown]
# #### Displaying unique values of City_Mileage column

# %%
ob_df["City_Mileage"].unique()
# Out:
# <StringArray>
# ['?23.6 km/litre',              nan, '21.38 km/litre', '25.17 km/litre',
#     '12 km/litre',    '11 km/litre',    '14 km/litre',    '19 km/litre',
#   '20.6 km/litre',    '23 km/litre',
#  ...
#    '8.4 km/litre', '15.01 km/litre',  '4.45 km/litre', '12.05 km/litre',
#   '15.8 km/litre',  '21,2 km/litre',     '2 km/litre',  '14.3 km/litre',
#   '22.6 km/litre',  '8.25 km/litre']
# Length: 165, dtype: str

# %% [markdown]
# #### Extracting numerical data from ARAI_Certified_Mileage column

# %%
ob_df["City_Mileage"] = (
    ob_df["City_Mileage"]
    .astype(str)
    .str.replace(",", ".")
    .str.replace("?", "", regex=False)
    .str.replace("km/litre", "", regex=False)
    .str.replace("kmpl", "", regex=False)
    .str.strip()
)
ob_df["City_Mileage"] = ob_df["City_Mileage"].apply(mileage_to_float)

# %% [markdown]
# #### Filling missing values

# %%
ob_df["City_Mileage"] = ob_df["City_Mileage"].fillna(value= ob_df["City_Mileage"].median())

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# * We are filling the missing values using the column’s median.

# %% [markdown]
# #### Missing values in ARAI_Certified_Mileage column

# %%
print("Total number of missing value: ", ob_df["City_Mileage"].isna().sum())
# Out:
# Total number of missing value:  0

# %% [markdown]
# #### Displaying unique values of Highway_Mileage column

# %%
ob_df["Highway_Mileage"].unique()
# Out:
# <StringArray>
# [             nan,    '24 km/litre',    '15 km/litre',    '17 km/litre',
#  '24.07 km/litre',    '23 km/litre',    '22 km/litre', '20.89 km/litre',
#     '16 km/litre',  '23.7 km/litre',
#  ...
#   '16.1 km/litre',  '7.94 km/litre',  '14.3 km/litre', '17.21 km/litre',
#  '16.21 km/litre',     '4 km/litre',  '16.4 km/litre',  '25.6 km/litre',
#   '25.1 km/litre', '11.56 km/litre']
# Length: 137, dtype: str

# %% [markdown]
# #### Extracting numerical data from Highway_Mileage column

# %%
ob_df["Highway_Mileage"] = (
    ob_df["Highway_Mileage"]
    .astype(str)
    .str.replace(",", ".")
    .str.replace("?", "", regex=False)
    .str.replace("km/litre", "", regex=False)
    .str.replace("kmpl", "", regex=False)
    .str.strip()
)
ob_df["Highway_Mileage"] = ob_df["Highway_Mileage"].apply(mileage_to_float)

# %% [markdown]
# #### Filling missing values

# %%
ob_df["Highway_Mileage"] = ob_df["Highway_Mileage"].fillna(value= ob_df["Highway_Mileage"].median())

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# * We are filling the missing values using the column’s median.

# %% [markdown]
# #### Missing values in Highway_Mileage column

# %%
print("Total number of missing value: ", ob_df["Highway_Mileage"].isna().sum())
# Out:
# Total number of missing value:  0

# %% [markdown]
# -----

# %% [markdown]
# <div style="background-color:lightgreen; padding:15px; border-radius:8px;">
#   <h2 style="text-align:center; margin:0;">Cleaning     "Fuel_Tank_Capacity",
#     "Boot_Space" columns</h2>
# </div>

# %% [markdown]
# -----

# %% [markdown]
# #### Displaying sample values

# %%
ob_df[["Fuel_Tank_Capacity",
    "Boot_Space"]].sample(5)
# Out:
#      Fuel_Tank_Capacity  Boot_Space
# 282           83 litres  520 litres
# 238           76 litres         NaN
# 1148          70 litres  421 litres
# 730           60 litres         NaN
# 8             28 litres  222 litres

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# * All the features are having **same unit of measure** which is **litres**
# * Hence we can simply **extract numerical values** and **convert its data-type.**

# %% [markdown]
# #### Displaying missing values

# %%
cols = ["Fuel_Tank_Capacity",
    "Boot_Space"]

# %%
ob_df[cols].isna().sum().to_frame(name = "Missing values")
# Out:
#                     Missing values
# Fuel_Tank_Capacity              69
# Boot_Space                     248

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# * Once the **numerical values** are extracted from the columns, they are converted to **float**
# * **Missing values** are imputed using the **column-wise median**.

# %% [markdown]
# #### Displaying unique values of Fuel_Tank_Capacity column

# %%
ob_df["Fuel_Tank_Capacity"].unique()
# Out:
# <StringArray>
# [  '24 litres',   '15 litres',   '28 litres',   '40 litres',   '35 litres',
#    '60 litres',   '32 litres',   '46 litres',   '45 litres',   '41 litres',
#    '44 litres',   '43 litres',   '42 litres',   '37 litres',   '50 litres',
#    '76 litres',   '70 litres',   '71 litres',   '57 litres',   '66 litres',
#    '56 litres',   '64 litres',           nan,   '54 litres',   '61 litres',
#    '74 litres',   '82 litres',   '83 litres',   '73 litres',   '67 litres',
#    '58 litres', '60.9 litres', '93.5 litres',   '80 litres',   '52 litres',
#   '100 litres',   '87 litres',   '65 litres',   '78 litres',   '85 litres',
#    '90 litres',   '96 litres',   '86 litres',   '93 litres',   '75 litres',
#    '92 litres', '82.5 litres',   '27 litres',   '48 litres',   '55 litres',
#    '63 litres',   '47 litres',   '51 litres', '67.5 litres',   '59 litres',
#    '68 litres',  '105 litres',   '91 litres',   '36 litres',   '62 litres',
# ...

# %% [markdown]
# #### Extracting numerical data from Highway_Mileage column

# %%
ob_df["Fuel_Tank_Capacity"] = ob_df["Fuel_Tank_Capacity"].apply(lambda x: str(x).split()[0]).astype(float)

# %% [markdown]
# #### Filling missing values

# %%
ob_df["Fuel_Tank_Capacity"] = ob_df["Fuel_Tank_Capacity"].fillna(value = ob_df["Fuel_Tank_Capacity"].median())

# %% [markdown]
# #### Missing values in Fuel_Tank_Capacity column

# %%
print("Total number of missing value: ", ob_df["Fuel_Tank_Capacity"].isna().sum())
# Out:
# Total number of missing value:  0

# %% [markdown]
# #### Displaying unique values of Boot_Space column

# %%
ob_df["Boot_Space"].unique()
# Out:
# <StringArray>
# [  '110 litres',    '94 litres',   '222 litres',   '300 litres',
#    '400 litres',   '250 litres',   '177 litres',   '265 litres',
#    '235 litres',            nan,
#  ...
#    '610 litres', '200.5 litres',   '310 litres',   '412 litres',
#     '54 litres',   '258 litres',   '476 litres',   '590 litres',
#    '598 litres',  '1050 litres']
# Length: 139, dtype: str

# %%
ob_df[ob_df["Boot_Space"] == '209(All3RowsUp).550(3rdRowFolded)&803(2ndRowand3rdRowFolded) litres'][["Make", "Model", "Boot_Space"]]
# Out:
#               Make   Model  \
# 930  Maruti Suzuki  Ertiga
# 931  Maruti Suzuki  Ertiga
# 932  Maruti Suzuki  Ertiga
# 933  Maruti Suzuki  Ertiga
# 934  Maruti Suzuki  Ertiga
# 935  Maruti Suzuki  Ertiga
# 936  Maruti Suzuki  Ertiga
# 937  Maruti Suzuki  Ertiga
# 938  Maruti Suzuki  Ertiga
#
#                                                               Boot_Space
# 930  209(All3RowsUp).550(3rdRowFolded)&803(2ndRowand3rdRowFolded) litres
# 931  209(All3RowsUp).550(3rdRowFolded)&803(2ndRowand3rdRowFolded) litres
# 932  209(All3RowsUp).550(3rdRowFolded)&803(2ndRowand3rdRowFolded) litres
# 933  209(All3RowsUp).550(3rdRowFolded)&803(2ndRowand3rdRowFolded) litres
# 934  209(All3RowsUp).550(3rdRowFolded)&803(2ndRowand3rdRowFolded) litres
# 935  209(All3RowsUp).550(3rdRowFolded)&803(2ndRowand3rdRowFolded) litres
# 936  209(All3RowsUp).550(3rdRowFolded)&803(2ndRowand3rdRowFolded) litres
# 937  209(All3RowsUp).550(3rdRowFolded)&803(2ndRowand3rdRowFolded) litres
# ...

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# * Boot space was provided for multiple seating configurations.
# * To maintain consistency, a single value was selected.
# * Therefore, the maximum boot space of 803 litres was used to represent the vehicle.

# %%
ob_df["Boot_Space"] = ob_df["Boot_Space"].replace(
    {"209(All3RowsUp).550(3rdRowFolded)&803(2ndRowand3rdRowFolded) litres" : "803 litres"}
)

# %% [markdown]
# #### Extracting numerical data from Boot_Space column

# %%
ob_df["Boot_Space"] = ob_df["Boot_Space"].apply(lambda x: str(x).split()[0]).astype(float)

# %% [markdown]
# #### Filling missing values

# %%
ob_df["Boot_Space"] = ob_df["Boot_Space"].fillna(value = ob_df["Boot_Space"].median())

# %% [markdown]
# #### Missing values in Boot_Space column

# %%
print("Total number of missing value: ", ob_df["Boot_Space"].isna().sum())
# Out:
# Total number of missing value:  0

# %% [markdown]
# -----

# %% [markdown]
# <div style="background-color:lightgreen; padding:15px; border-radius:8px;">
#   <h2 style="text-align:center; margin:0;">Cleaning     "Drivetrain",
#     "Gears",
#     "Front_Suspension",
#     "Rear_Suspension",
#     "Front_Brakes",
#     "Rear_Brakes"
#  columns</h2>
# </div>

# %% [markdown]
# -----

# %% [markdown]
# ### 01. Cleaning Gears column

# %% [markdown]
# #### Displaying sample values

# %%
ob_df["Gears"].sample(5).to_frame()
# Out:
#      Gears
# 968      5
# 753      7
# 964      5
# 1229     7
# 374      5

# %% [markdown]
# #### Displayin unique values

# %%
ob_df["Gears"].unique()
# Out:
# <StringArray>
# [                          '4',                           '5',
#                            '6',                           nan,
#                            '7',                           '9',
#                            '8',               '7 Dual Clutch',
#  'Single Speed Reduction Gear']
# Length: 9, dtype: str

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# * Some values in the column contain **mixed data**.
# * For example, **7 Dual Clutch** should be standardized to **7**.
# * **Single Speed Reduction Gear** should be converted to **1**.

# %%
ob_df["Gears"] = ob_df["Gears"].replace(
    {"7 Dual Clutch" : "7",
    "Single Speed Reduction Gear" : "1"}
).astype(float)

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# * The column is initially converted to a float data type to allow median-based imputation of missing values.
# * Once the missing values are handled, the column is converted back to an integer data type.

# %% [markdown]
# #### Missing values in Gears column

# %%
print("Total number of missing values :", ob_df["Gears"].isna().sum())
# Out:
# Total number of missing values : 105

# %% [markdown]
# #### Filling missing values

# %%
ob_df["Gears"] = ob_df["Gears"].fillna(value = ob_df["Gears"].median())

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# * Missing values are imputed using the median of the column.

# %% [markdown]
# #### Missing values in Gears column

# %%
print("Total number of missing values :", ob_df["Gears"].isna().sum())
# Out:
# Total number of missing values : 0

# %% [markdown]
# #### Changing the data type of Gears column

# %%
ob_df["Gears"] = ob_df["Gears"].astype(int)

# %% [markdown]
# ----

# %% [markdown]
# ### 02. Cleaning Drivetrain column

# %% [markdown]
# #### Displaying sample values

# %%
ob_df["Drivetrain"].sample(5).to_frame()
# Out:
#                    Drivetrain
# 83    FWD (Front Wheel Drive)
# 308     AWD (All Wheel Drive)
# 996   FWD (Front Wheel Drive)
# 1124  FWD (Front Wheel Drive)
# 1068  FWD (Front Wheel Drive)

# %% [markdown]
# #### Displaying unique values

# %%
ob_df["Drivetrain"].unique()
# Out:
# <StringArray>
# [ 'RWD (Rear Wheel Drive)', 'FWD (Front Wheel Drive)',
#    'AWD (All Wheel Drive)',                     '4WD',
#                        nan]
# Length: 5, dtype: str

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# * The bracketed descriptions can be removed, as their meanings are already documented in the metadata.

# %%
ob_df["Drivetrain"] = (
    ob_df["Drivetrain"]
    .astype(str)
    .str.split()
    .str[0]
    .replace("nan", np.nan)
    .astype("object")
)

# %% [markdown]
# #### Missing values in Drivetrain column

# %%
print("Total number of missing values: ", ob_df["Drivetrain"].isna().sum())
# Out:
# Total number of missing values:  7

# %% [markdown]
# #### Filling missing values

# %%
ob_df[ob_df["Drivetrain"].isna()][["Make", "Model", "Drivetrain"]]
# Out:
#                Make              Model Drivetrain
# 272            Mini            Clubman        NaN
# 303   Mercedes-Benz  E-Class Cabriolet        NaN
# 503            Tata              Nexon        NaN
# 843        Maserati             Ghibli        NaN
# 844        Maserati             Ghibli        NaN
# 845        Maserati             Ghibli        NaN
# 1162         Jaguar             F-Type        NaN

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# * **Based on online research and manufacturer specifications, drivetrain values were assigned as follows:**
#
# **1.** Mini Clubman = AWD
# **2.** Mercedes-Benz E-Class Cabriolet = RWD
# **3.** Tata Nexon = FWD
# **4.** Maserati Ghibli = RWD
# **5.** Jaguar F-Type = RWD

# %%
# Mini Clubman
mask1 = (ob_df["Make"] == "Mini") & (ob_df["Model"] == "Clubman") & (ob_df["Drivetrain"].isna())

ob_df.loc[mask1, "Drivetrain"] = "AWD"

# Mercedes-Benz E-Class Cabriolet
mask2 = (ob_df["Make"] == "Mercedes-Benz") & (ob_df["Model"] == "E-Class Cabriolet") & (ob_df["Drivetrain"].isna())

ob_df.loc[mask2, "Drivetrain"] = "RWD"

# Tata Nexon
mask3 = (ob_df["Make"] == "Tata") & (ob_df["Model"] == "Nexon") & (ob_df["Drivetrain"].isna())

ob_df.loc[mask3, "Drivetrain"] = "FWD"

# Maserati Ghibli
mask4 = (ob_df["Make"] == "Maserati") & (ob_df["Model"] == "Ghibli") & (ob_df["Drivetrain"].isna())
ob_df.loc[mask4, "Drivetrain"] = "RWD"

# Jaguar F-Type
mask5 = (ob_df["Make"] == "Jaguar") & (ob_df["Model"] == "F-Type") & (ob_df["Drivetrain"].isna())
ob_df.loc[mask5, "Drivetrain"] = "RWD"

# %% [markdown]
# #### Missing values in Drivetrain column

# %%
print("Total number of missing values: ", ob_df["Drivetrain"].isna().sum())
# Out:
# Total number of missing values:  0

# %% [markdown]
# -----

# %% [markdown]
# ### 03. Cleaning Front_Suspension column

# %% [markdown]
# #### Displaying sample values

# %%
ob_df["Front_Suspension"].sample(5).to_frame()
# Out:
#                  Front_Suspension
# 46                            NaN
# 252               McPherson Strut
# 32    Gas Filled Mc Pherson Strut
# 950               Double wishbone
# 1203                          NaN

# %% [markdown]
# #### Missing values in Front_Suspension column

# %%
print("Total number of missing values :", ob_df["Front_Suspension"].isna().sum())
# Out:
# Total number of missing values : 59

# %% [markdown]
# #### Displaying unique values

# %%
ob_df["Front_Suspension"].unique()
# Out:
# <StringArray>
# [                                                         'Independent, Lower Wishbone, McPherson Strut with gas filled dampers and anti-roll bar',
#                                                                                                                                 'Double Pivot Arm',
#                                                                                        'Mac Pherson strut with Lower Transverse link, coil spring',
#                                                                                                    'MacPherson Struts With Lower Transverse Links',
#                                                                                                                                 'McPherson struts',
#                                                                                                                                  'McPherson Strut',
# ...

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# * Since this column has a large number of unique values and each value is a long description.
# * we need to refer to the car’s make and model columns.

# %%
ob_df[ob_df["Front_Suspension"].isna()][["Make", "Model", "Front_Suspension"]]
# Out:
#                Make                Model Front_Suspension
# 46          Hyundai               Santro              NaN
# 47          Hyundai               Santro              NaN
# 48          Hyundai               Santro              NaN
# 53          Hyundai               Santro              NaN
# 267            Mini        Cooper 5 Door              NaN
# 275            Mini    John Cooper Works              NaN
# 355         Bugatti               Chiron              NaN
# 440            Icml              Extreme              NaN
# 441            Icml              Extreme              NaN
# 442            Icml              Extreme              NaN
# 443            Icml              Extreme              NaN
# 444            Icml              Extreme              NaN
# 445            Icml              Extreme              NaN
# 446            Icml              Extreme              NaN
# 447            Icml              Extreme              NaN
# ...

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# * Filling these missing values would require researching each car individually, which is not feasible due to the large number of vehicles.
# * Therefore, the missing values are filled as **‘Not Defined’**.

# %% [markdown]
# #### Filling missing values

# %%
ob_df["Front_Suspension"] = ob_df["Front_Suspension"].fillna(value = "Not Defined")

# %% [markdown]
# #### Missing value in Front_Suspension column

# %%
print("Total number of missing values :", ob_df["Front_Suspension"].isna().sum())
# Out:
# Total number of missing values : 0

# %% [markdown]
# ----

# %% [markdown]
# ### 04. Cleaning Rear_Suspension column

# %% [markdown]
# #### Displaying sample values

# %%
ob_df["Rear_Suspension"].sample(5).to_frame()
# Out:
#                                                                                     Rear_Suspension
# 132                                                      Coupled Torsion Beam Axle with coil spring
# 1249  Multi-element axle, with one longitudinal and three transverse links, with torsion stabiliser
# 986                                             Torsion beam axle with coil springs & anti-roll bar
# 567                                   Trailing arm with coil springs & double acting shock absorber
# 500                                                      Coupled Torsion Beam Axle with coil spring

# %% [markdown]
# #### Missing values in Rear_Suspension column

# %%
print("Total number of missing values :", ob_df["Rear_Suspension"].isna().sum())
# Out:
# Total number of missing values : 46

# %% [markdown]
# #### Displaying unique values

# %%
ob_df["Rear_Suspension"].unique()
# Out:
# <StringArray>
# ['Independent, Semi Trailing arm with coil spring & gas filled shock absorbers',
#                                                           'H-type Torsion Beam',
#                                        'Twist beam suspension with coil spring',
#                                                                  '3 Link Rigid',
#                                                  '3-link rigid axle Suspension',
#                                    'Coupled Torsion Beam Axle with coil spring',
#                                                                             nan,
#                                                     'Coupled Torsion Beam Axle',
#                             'Semi-Independent; Twist beam with dual path strut',
#         'Rear Twist beam with coil spring mounted on hydraulic shock absorbers',
#  ...
#                                            'Torsion Beam link with coil spring',
# ...

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# * Since this column has a large number of unique values and each value is a long description.
# * we need to refer to the car’s make and model columns.

# %%
ob_df[ob_df["Rear_Suspension"].isna()][["Make", "Model", "Front_Suspension"]]
# Out:
#                Make                Model Front_Suspension
# 46          Hyundai               Santro      Not Defined
# 47          Hyundai               Santro      Not Defined
# 48          Hyundai               Santro      Not Defined
# 53          Hyundai               Santro      Not Defined
# 267            Mini        Cooper 5 Door      Not Defined
# 275            Mini    John Cooper Works      Not Defined
# 355         Bugatti               Chiron      Not Defined
# 596         Renault                Lodgy      Not Defined
# 600         Renault                Lodgy      Not Defined
# 601         Renault                Lodgy      Not Defined
# 633           Force               Gurkha      Not Defined
# 634           Force               Gurkha      Not Defined
# 781             Bmw             3-Series      Not Defined
# 782             Bmw             3-Series      Not Defined
# 809   Mercedes-Benz              V-Class      Not Defined
# ...

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# * Filling these missing values would require researching each car individually, which is not feasible due to the large number of vehicles.
# * Therefore, the missing values are filled as **‘Not Defined’**.

# %% [markdown]
# #### Filling missing values

# %%
ob_df["Rear_Suspension"] = ob_df["Rear_Suspension"].fillna(value = "Not Defined")

# %% [markdown]
# #### Missing value in Rear_Suspension column

# %%
print("Total number of missing values :", ob_df["Rear_Suspension"].isna().sum())
# Out:
# Total number of missing values : 0

# %% [markdown]
# -----

# %% [markdown]
# ### 05. Cleaning Front_Brakes and Rear_Brakes column

# %% [markdown]
# #### Displaying sample values

# %%
ob_df[["Front_Brakes", "Rear_Brakes"]].sample(5)
# Out:
#         Front_Brakes      Rear_Brakes
# 829  Ventilated Disc  Ventilated Disc
# 249       Solid Disc       Solid Disc
# 848       Solid Disc       Solid Disc
# 641  Ventilated Disc             Drum
# 462  Ventilated Disc             Drum

# %% [markdown]
# #### Displaying unique values

# %%
print("Unique values of Front_Brakes: ",ob_df["Front_Brakes"].unique())
print("-"*80)
print("Unique values of Rear_Brakes: ",ob_df["Rear_Brakes"].unique())
# Out:
# Unique values of Front_Brakes:  <StringArray>
# ['Drum', 'Ventilated Disc', nan, 'Solid Disc']
# Length: 4, dtype: str
# --------------------------------------------------------------------------------
# Unique values of Rear_Brakes:  <StringArray>
# ['Drum', nan, 'Ventilated Disc', 'Solid Disc']
# Length: 4, dtype: str

# %% [markdown]
# #### Missing values in Front_Brakes and Rear_Brakes column

# %%
print("Total number of missing values :", ob_df["Front_Brakes"].isna().sum())
print("Total number of missing values :", ob_df["Rear_Brakes"].isna().sum())
# Out:
# Total number of missing values : 25
# Total number of missing values : 25

# %% [markdown]
# #### Filling missing values in Front_Brakes column

# %%
ob_df[ob_df["Front_Brakes"].isna()][["Make", "Model", "Rear_Brakes", "Front_Brakes"]]
# Out:
#           Make   Model Rear_Brakes Front_Brakes
# 46     Hyundai  Santro         NaN          NaN
# 47     Hyundai  Santro         NaN          NaN
# 48     Hyundai  Santro         NaN          NaN
# 53     Hyundai  Santro         NaN          NaN
# 499    Hyundai   Venue         NaN          NaN
# 843   Maserati  Ghibli         NaN          NaN
# 844   Maserati  Ghibli         NaN          NaN
# 845   Maserati  Ghibli         NaN          NaN
# 997         Mg  Hector         NaN          NaN
# 998         Mg  Hector         NaN          NaN
# 999         Mg  Hector         NaN          NaN
# 1000        Mg  Hector         NaN          NaN
# 1001        Mg  Hector         NaN          NaN
# 1002        Mg  Hector         NaN          NaN
# 1004        Mg  Hector         NaN          NaN
# 1005        Mg  Hector         NaN          NaN
# 1162    Jaguar  F-Type         NaN          NaN
# 1196    Nissan   Kicks         NaN          NaN
# 1197    Nissan   Kicks         NaN          NaN
# ...

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# * Since we only have six cars with missing values, we can fill them with suitable values after some online research.

# %%
ob_df.loc[
    ob_df["Front_Brakes"].isna() &
    (
        ((ob_df["Make"] == "Hyundai") & (ob_df["Model"].isin(["Santro", "Venue"]))) |
        ((ob_df["Make"] == "Mg") & (ob_df["Model"] == "Hector")) |
        ((ob_df["Make"] == "Nissan") & (ob_df["Model"] == "Kicks"))
    ),
    ["Front_Brakes", "Rear_Brakes"]
] = ["Solid Disc", "Solid Disc"]


ob_df.loc[
    ob_df["Front_Brakes"].isna() &
    (
        ((ob_df["Make"] == "Maserati") & (ob_df["Model"] == "Ghibli")) |
        ((ob_df["Make"] == "Jaguar") & (ob_df["Model"] == "F-Type"))
    ),
    ["Front_Brakes", "Rear_Brakes"]
] = ["Ventilated Disc", "Ventilated Disc"]



ob_df["Front_Brakes"] = ob_df["Front_Brakes"].fillna("Drum")
ob_df["Rear_Brakes"] = ob_df["Rear_Brakes"].fillna("Drum")

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# * Based on online research and manufacturer specifications, the missing front and rear brake values were assigned as follows:
# 1. Hyundai Santro = Solid Disc (Front), Solid Disc (Rear)
# 2. Hyundai Venue = Solid Disc (Front), Solid Disc (Rear)
# 3. MG Hector = Solid Disc (Front), Solid Disc (Rear)
# 4. Nissan Kicks = Solid Disc (Front), Solid Disc (Rear)
# 5. Maserati Ghibli = Ventilated Disc (Front), Ventilated Disc (Rear)
# 6. Jaguar F-Type = Ventilated Disc (Front), Ventilated Disc (Rear)

# %% [markdown]
# #### Missing value in Front_Suspension column

# %%
print("Total number of missing values :", ob_df["Front_Brakes"].isna().sum())
print("Total number of missing values :", ob_df["Rear_Brakes"].isna().sum())
# Out:
# Total number of missing values : 0
# Total number of missing values : 0

# %% [markdown]
# -----

# %% [markdown]
# <div style="background-color:lightgreen; padding:15px; border-radius:8px;">
#   <h2 style="text-align:center; margin:0;">Cleaning "Airbags",
#     "ABS_(Anti-lock_Braking_System)",
#     "EBD_(Electronic_Brake-force_Distribution)",
#     "ESP_(Electronic_Stability_Program)",
#     "Hill_Assist",
#     "ISOFIX_(Child-Seat_Mount)"
#  columns</h2>
# </div>

# %% [markdown]
# ### 01. Cleaning Airbags column

# %% [markdown]
# #### Displaying sample values

# %%
ob_df["Airbags"].sample(5).to_frame()
# Out:
#                                                                                                                                                                                            Airbags
# 575                                                                         Front passenger frontal airbag, Front passenger side airbag, Drive side airbag, Curtain airbags, Driver frontal airbag
# 1129                                                                                                                                         Driver frontal airbag, Front passenger frontal airbag
# 286   Rear passenger curtain airbags, Driver frontal airbag, Front passenger frontal airbag, Front passenger side airbag, Drive side airbag, Front passenger curtain airbag, Driver curtain airbag
# 640                                                                                                                                                                          Driver frontal airbag
# ...

# %% [markdown]
# #### Missing values in Airbags column

# %%
print("Total number of missing values: ", ob_df["Airbags"].isna().sum())
# Out:
# Total number of missing values:  132

# %% [markdown]
# #### Displaying unique values

# %%
ob_df["Airbags"].nunique()
# Out:
# 207

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# * Since this column has a large number of unique values and each value is a long description.
# * we need to refer to the car’s make and model columns.

# %%
ob_df[ob_df["Airbags"].isna()][["Make", "Model"]].shape
# Out:
# (132, 2)

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# * Filling these missing values would require researching each car individually, which is not feasible due to the large number of vehicles.
# * Therefore, the missing values are filled as **‘Not Defined’**.

# %% [markdown]
# #### Filling missing values

# %%
ob_df["Airbags"] = ob_df["Airbags"].fillna(value = "Not Defined")

# %% [markdown]
# #### Missing values in Airbags column

# %%
print("Total number of missing values: ", ob_df["Airbags"].isna().sum())
# Out:
# Total number of missing values:  0

# %% [markdown]
# -----

# %% [markdown]
# ### 02. Cleaning ABS (Anti-lock Braking System) and EBD (Electronic Brake-force Distribution) columns

# %% [markdown]
# #### Displaying sample values

# %%
ob_df[["ABS_(Anti-lock_Braking_System)",
    "EBD_(Electronic_Brake-force_Distribution)"]].sample(10)
# Out:
#      ABS_(Anti-lock_Braking_System) EBD_(Electronic_Brake-force_Distribution)
# 353                             NaN                                       NaN
# 163                             Yes                                       Yes
# 1234                            Yes                                       Yes
# 357                             NaN                                       NaN
# 918                             Yes                                       Yes
# 644                             Yes                                       Yes
# 1149                            Yes                                       Yes
# 780                             Yes                                       Yes
# 1155                            Yes                                       Yes
# 964                             NaN                                       NaN

# %% [markdown]
# #### Missing values in ABS_(Anti-lock_Braking_System) and EBD_(Electronic_Brake-force_Distribution) columns

# %%
print("Total number of missing values in ABS_(Anti-lock_Braking_System) column: ", ob_df["ABS_(Anti-lock_Braking_System)"].isna().sum())
print("-"*80)
print("Total number of missing values in EBD_(Electronic_Brake-force_Distribution) column: ", ob_df["EBD_(Electronic_Brake-force_Distribution)"].isna().sum())
# Out:
# Total number of missing values in ABS_(Anti-lock_Braking_System) column:  131
# --------------------------------------------------------------------------------
# Total number of missing values in EBD_(Electronic_Brake-force_Distribution) column:  200

# %% [markdown]
# #### Displaying unique values of ABS_(Anti-lock_Braking_System) and EBD_(Electronic_Brake-force_Distribution) columns

# %%
print("Unique values of ABS_(Anti-lock_Braking_System) column: ", ob_df["ABS_(Anti-lock_Braking_System)"].unique())
print("-"*80)
print("Unique values of EBD_(Electronic_Brake-force_Distribution) column: ", ob_df["EBD_(Electronic_Brake-force_Distribution)"].unique())
# Out:
# Unique values of ABS_(Anti-lock_Braking_System) column:  <StringArray>
# [nan, 'Yes']
# Length: 2, dtype: str
# --------------------------------------------------------------------------------
# Unique values of EBD_(Electronic_Brake-force_Distribution) column:  <StringArray>
# [nan, 'Yes']
# Length: 2, dtype: str

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# * In both **ABS_(Anti-lock_Braking_System)** and **EBD_(Electronic_Brake-force_Distribution)** columns, we have only **two unique values**, one of which is a **missing value**.
# If we perform a groupby operation using the **Make** and **Model** columns, all missing values would be filled with **Yes**,
# which could be a **wrong value for that car**.
#
# * Therefore, we fill the missing values with **"Undefined"** so that we **do not make wrong assumptions** about the car.

# %% [markdown]
# #### Filling missing values in ABS_(Anti-lock_Braking_System) and EBD_(Electronic_Brake-force_Distribution) columns

# %%
cols = ["ABS_(Anti-lock_Braking_System)", "EBD_(Electronic_Brake-force_Distribution)"]

for col in cols:
    ob_df[col] = ob_df[col].fillna(value = "Undefined")

# %% [markdown]
# #### Missing values in ABS_(Anti-lock_Braking_System) and EBD_(Electronic_Brake-force_Distribution) columns

# %%
print("Total number of missing values: ", ob_df["ABS_(Anti-lock_Braking_System)"].isna().sum())
print("-"*80)
print("Total number of missing values: ", ob_df["EBD_(Electronic_Brake-force_Distribution)"].isna().sum())
# Out:
# Total number of missing values:  0
# --------------------------------------------------------------------------------
# Total number of missing values:  0

# %% [markdown]
# -----

# %% [markdown]
# ### 03. Cleaning ESP_(Electronic_Stability_Program), Hill_Assist and ISOFIX_(Child-Seat_Mount) columns

# %%
cols = ["ESP_(Electronic_Stability_Program)",
    "Hill_Assist",
    "ISOFIX_(Child-Seat_Mount)"]

# %% [markdown]
# #### Displaying sample values

# %%
ob_df[cols].sample(10)
# Out:
#      ESP_(Electronic_Stability_Program) Hill_Assist ISOFIX_(Child-Seat_Mount)
# 242                                 Yes         Yes                       Yes
# 369                                 NaN         NaN                       NaN
# 998                                 Yes         NaN                       NaN
# 814                                 Yes         Yes                       Yes
# 396                                 NaN         NaN                       NaN
# 1222                                NaN         NaN                       NaN
# 208                                 NaN         NaN                       NaN
# 397                                 NaN         NaN                       NaN
# 664                                 Yes         NaN                       Yes
# 325                                 Yes         Yes                       Yes

# %% [markdown]
# #### Missing values in ESP_(Electronic_Stability_Program), Hill_Assist and ISOFIX_(Child-Seat_Mount) columns

# %%
for col in cols:
    print(f"Total number of missing values in {col} column: {ob_df[col].isna().sum()}")
    print("-"*80)
# Out:
# Total number of missing values in ESP_(Electronic_Stability_Program) column: 778
# --------------------------------------------------------------------------------
# Total number of missing values in Hill_Assist column: 795
# --------------------------------------------------------------------------------
# Total number of missing values in ISOFIX_(Child-Seat_Mount) column: 657
# --------------------------------------------------------------------------------

# %% [markdown]
# #### Displaying unique values

# %%
for col in cols:
    print(f"Unique values of {col} column: {ob_df[col].unique()}")
    print("-"*80)
# Out:
# Unique values of ESP_(Electronic_Stability_Program) column: <StringArray>
# [nan, 'Yes']
# Length: 2, dtype: str
# --------------------------------------------------------------------------------
# Unique values of Hill_Assist column: <StringArray>
# [nan, 'Yes']
# Length: 2, dtype: str
# --------------------------------------------------------------------------------
# Unique values of ISOFIX_(Child-Seat_Mount) column: <StringArray>
# [nan, 'Yes']
# Length: 2, dtype: str
# --------------------------------------------------------------------------------

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# * For **ESP_(Electronic_Stability_Program)** and **Hill_Assist**  **ISOFIX_(Child-Seat_Mount)** columns, we have only **two unique values**, one of which is a **missing value**.
# If we perform a groupby operation using the **Make** and **Model** columns, all missing values would be filled with **Yes**,
# which could be a **wrong value for that car**.
#
# * Therefore, we fill the missing values with **"Undefined"** so that we **do not make wrong assumptions** about the car.

# %% [markdown]
# #### Filling missing values in ESP_(Electronic_Stability_Program), Hill_Assist and ISOFIX_(Child-Seat_Mount) columns

# %%
for col in cols:
    ob_df[col] = ob_df[col].fillna(value = "Undefined")

# %% [markdown]
# #### Missing values in ESP_(Electronic_Stability_Program), Hill_Assist and ISOFIX_(Child-Seat_Mount) columns

# %%
for col in cols:
    print(f"Total number of missing values in {col} column: {ob_df[col].isna().sum()}")
    print("-"*80)
# Out:
# Total number of missing values in ESP_(Electronic_Stability_Program) column: 0
# --------------------------------------------------------------------------------
# Total number of missing values in Hill_Assist column: 0
# --------------------------------------------------------------------------------
# Total number of missing values in ISOFIX_(Child-Seat_Mount) column: 0
# --------------------------------------------------------------------------------

# %% [markdown]
# ------

# %% [markdown]
# <div style="background-color:lightgreen; padding:15px; border-radius:8px;">
#   <h2 style="text-align:center; margin:0;">Cleaning "Power_Steering",
#     "Power_Windows",
#     "Central_Locking",
#     "Keyless_Entry"
#  columns</h2>
# </div>

# %% [markdown]
# -----

# %%
cols = ["Power_Steering",
    "Power_Windows",]

# %% [markdown]
# ### 01. Cleaning Power_Steering and  Power_Windows column

# %% [markdown]
# #### Displaying sample values

# %%
ob_df[cols].sample(5)
# Out:
#         Power_Steering Power_Windows
# 845                Yes           NaN
# 308     Electric Power   All Windows
# 42      Electric Power   All Windows
# 792  Electro-Hydraulic   All Windows
# 59      Electric Power   All Windows

# %% [markdown]
# #### Missing values of Power_Steering and Power_Windows columns

# %%
for col in cols:
    print(f"Total number of missing values of {col} column: {ob_df[col].isna().sum()}")
    print("-"*80)
# Out:
# Total number of missing values of Power_Steering column: 57
# --------------------------------------------------------------------------------
# Total number of missing values of Power_Windows column: 97
# --------------------------------------------------------------------------------

# %% [markdown]
# #### Displaying unique values

# %%
for col in cols:
    print(f"Unique values of {col} column:\n {ob_df[col].unique()}")
    print("-"*80)
# Out:
# Unique values of Power_Steering column:
#  <StringArray>
# [                 'Electric Power',                               nan,
#                              'Yes',                 'Hydraulic Power',
#  'Electric Power, Hydraulic Power',               'Electro-Hydraulic']
# Length: 6, dtype: str
# --------------------------------------------------------------------------------
# Unique values of Power_Windows column:
#  <StringArray>
# ['Only Front Windows', nan, 'All Windows']
# Length: 3, dtype: str
# --------------------------------------------------------------------------------

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# * The value **‘Electric Power, Hydraulic Power’** indicates a hybrid steering mechanism. Since Electro-Hydraulic Power Steering combines both electric and hydraulic components, this value was standardized to **‘Electro-Hydraulic**.

# %% [markdown]
# #### Filling missing values and handling Ambiguous values

# %%
ob_df["Power_Steering"] = ob_df["Power_Steering"].replace({"Electric Power, Hydraulic Power" :  "Electro-Hydraulic"})

# %%
ob_df[ob_df["Power_Steering"].isna()][["Make", "Model", "Power_Steering", "Power_Windows"]]
# Out:
#                Make                Model Power_Steering       Power_Windows
# 1              Tata            Nano Genx            NaN                 NaN
# 6            Datsun              Redi-Go            NaN                 NaN
# 12          Renault                 Kwid            NaN                 NaN
# 13          Renault                 Kwid            NaN                 NaN
# 24    Maruti Suzuki                 Eeco            NaN                 NaN
# 25    Maruti Suzuki                 Eeco            NaN                 NaN
# 26    Maruti Suzuki                 Eeco            NaN                 NaN
# 27    Maruti Suzuki                 Eeco            NaN                 NaN
# 28    Maruti Suzuki                 Eeco            NaN                 NaN
# 31    Maruti Suzuki             Alto K10            NaN                 NaN
# 35           Datsun                   Go            NaN  Only Front Windows
# ...

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# * We can fill the missing values using the mode calculated within each Make–Model group.

# %%
for col in cols:
    ob_df[col] = ob_df[col].fillna(
        ob_df.groupby(["Make", "Model"])[col].transform(lambda x: x.mode().iloc[0] if not x.mode().empty else np.nan)
    )

# %%
ob_df[ob_df["Power_Steering"].isna()][["Make", "Model", "Power_Steering", "Power_Windows"]]
# Out:
#               Make                Model Power_Steering       Power_Windows
# 24   Maruti Suzuki                 Eeco            NaN                 NaN
# 25   Maruti Suzuki                 Eeco            NaN                 NaN
# 26   Maruti Suzuki                 Eeco            NaN                 NaN
# 27   Maruti Suzuki                 Eeco            NaN                 NaN
# 28   Maruti Suzuki                 Eeco            NaN                 NaN
# 353    Rolls-Royce             Cullinan            NaN                 NaN
# 357          Bajaj          Qute (Re60)            NaN                 NaN
# 358          Bajaj          Qute (Re60)            NaN                 NaN
# 440           Icml              Extreme            NaN         All Windows
# 441           Icml              Extreme            NaN         All Windows
# 442           Icml              Extreme            NaN         All Windows
# ...

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# * After the groupby operation, only 7 cars remained.
# * Based on online research, the following values were identified for each car
#
#
#
# 1. Maruti Suzuki Eeco (Power Steering: No, Power Windows: No),
# 2. Maruti Suzuki Gypsy (Power Steering: No, Power Windows: No),
# 3. Maruti Suzuki Omni (Power Steering: No, Power Windows: No),
# 4. Bajaj Qute RE60 (Power Steering: No, Power Windows: No),
# 5. Rolls-Royce Cullinan (Power Steering: Yes, Power Windows: All Windows),
# 6. Mercedes-Benz AMG GT 4-Door Coupe (Power Steering: Yes, Power Windows: All Windows),
# 7. ICML Extreme (Power Steering: Unknown).
# * **ICML Extreme** was assigned **‘Unknown**’ values due to the **absence of reliable and consistent feature** specifications across **publicly available sources**.

# %%
# Make and Model values where Power_Steering or Power_Windows are missing.
cols1 = [
    ("Maruti Suzuki", "Eeco"),
    ("Maruti Suzuki", "Gypsy"),
    ("Maruti Suzuki", "Omni"),
    ("Bajaj", "Qute (Re60)"),
    ("Rolls-Royce", "Cullinan"),
    ("Mercedes-Benz", "Amg Gt 4-Door Coupe"),
    ("Icml", "Extreme")
]

# values of Power_Steering and Power_Windows.
cols2 = [
    ["No", "No"],
    ["No", "No"],
    ["No", "No"],
    ["No", "No"],
    ["Yes", "All Windows"],
    ["Yes", "All Windows"],
    ["Unknown", "Unknown"]
]

for i in range(len(cols2)):
    mask = (ob_df["Make"] == cols1[i][0]) & (ob_df["Model"] == cols1[i][1]) 

    ob_df.loc[mask, "Power_Steering"] = ob_df.loc[mask, "Power_Steering"].fillna(value = cols2[i][0])
    ob_df.loc[mask, "Power_Windows"] = ob_df.loc[mask, "Power_Windows"].fillna(value = cols2[i][1])

# %%
ob_df[ob_df["Power_Windows"].isna()][["Make", "Model", "Power_Windows"]]
# Out:
#           Make   Model Power_Windows
# 628   Mahindra    Thar           NaN
# 629   Mahindra    Thar           NaN
# 630   Mahindra    Thar           NaN
# 843   Maserati  Ghibli           NaN
# 844   Maserati  Ghibli           NaN
# 845   Maserati  Ghibli           NaN
# 995         Mg  Hector           NaN
# 996         Mg  Hector           NaN
# 997         Mg  Hector           NaN
# 998         Mg  Hector           NaN
# 999         Mg  Hector           NaN
# 1000        Mg  Hector           NaN
# 1001        Mg  Hector           NaN
# 1002        Mg  Hector           NaN
# 1003        Mg  Hector           NaN
# 1004        Mg  Hector           NaN
# 1005        Mg  Hector           NaN
# 1204      Tata  Winger           NaN

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# * Since only four cars remain, we can research the Power_Windows feature for each vehicle online and fill the remaining missing values.
#
# * Based on online research, the following values were determined.
# 1. Mahindra Thar → All Windows
#
# 2. Maserati Ghibli → All Windows
#
# 3. MG Hector → All Windows
#
# 4. Tata Winger → Only Front Windows

# %%
col1 = ["Mahindra", "Maserati", "Mg"]

col2 = ["Thar", "Ghibli", "Hector"]

for i in range(len(col1)):
    mask = (ob_df["Make"] == col1[i]) & (ob_df["Model"] == col2[i])
    ob_df.loc[mask, "Power_Windows"] = ob_df.loc[mask, "Power_Windows"].fillna(value = "All Windows")

mask2 = (ob_df["Make"] == "Tata") & (ob_df["Model"] == "Winger")
ob_df.loc[mask2, "Power_Windows"] = ob_df.loc[mask2, "Power_Windows"].fillna(value = "Only Front Windows")

# %% [markdown]
# #### Missing values of Power_Steering and Power_Windows columns`

# %%
for col in cols:
    print(f"Total number of missing values of {col} column: {ob_df[col].isna().sum()}")
    print("-"*80)
# Out:
# Total number of missing values of Power_Steering column: 0
# --------------------------------------------------------------------------------
# Total number of missing values of Power_Windows column: 0
# --------------------------------------------------------------------------------

# %% [markdown]
# -----

# %% [markdown]
# ### 02. Cleaning Central_Locking and Keyless_Entry columns

# %%
cols= ["Keyless_Entry","Central_Locking"]

# %% [markdown]
# #### Displaying sample values

# %%
ob_df[cols].sample(5)
# Out:
#          Keyless_Entry Central_Locking
# 652             Remote             Yes
# 501                NaN             Yes
# 275  Remote, Smart Key             Yes
# 288          Smart Key             Yes
# 162             Remote             Yes

# %% [markdown]
# #### Missing values in Keyless_Entry and Central_Locking columns

# %%
for col in cols:
    print(f"Total number of missing values in {col} column: {ob_df[col].isna().sum()}")
    print("-"*80)
# Out:
# Total number of missing values in Keyless_Entry column: 274
# --------------------------------------------------------------------------------
# Total number of missing values in Central_Locking column: 148
# --------------------------------------------------------------------------------

# %% [markdown]
# #### Displaying unique values

# %%
for col in cols:
    print(f"Unique values of {col} column: {ob_df[col].unique()}")
    print("-"*80)
# Out:
# Unique values of Keyless_Entry column: <StringArray>
# ['Remote', nan, 'Yes', 'Smart Key', 'Remote, Smart Key', 'Smart Key, Remote']
# Length: 6, dtype: str
# --------------------------------------------------------------------------------
# Unique values of Central_Locking column: <StringArray>
# ['Yes', nan]
# Length: 2, dtype: str
# --------------------------------------------------------------------------------

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# * We have duplicate unique values in the Keyless_Entry column,
# * so one occurrence of **"Smart Key, Remote"** needs to be changed to **"Remote, Smart Key"**

# %% [markdown]
# #### Filling Missing values and removing Duplicates

# %%
ob_df[cols[0]] = ob_df[cols[0]].replace({"Smart Key, Remote" : "Remote, Smart Key"})

# %%
ob_df[ob_df[cols[0]].isna()][["Make", "Model", "Keyless_Entry", "Central_Locking"]]
# Out:
#                Make                Model Keyless_Entry Central_Locking
# 1              Tata            Nano Genx           NaN             NaN
# 2              Tata            Nano Genx           NaN             NaN
# 4              Tata            Nano Genx           NaN             NaN
# 5              Tata            Nano Genx           NaN             NaN
# 6            Datsun              Redi-Go           NaN             NaN
# 7            Datsun              Redi-Go           NaN             Yes
# 8            Datsun              Redi-Go           NaN             NaN
# 9            Datsun              Redi-Go           NaN             NaN
# 10           Datsun              Redi-Go           NaN             NaN
# 12          Renault                 Kwid           NaN             NaN
# 13          Renault                 Kwid           NaN             NaN
# 14          Renault                 Kwid           NaN             Yes
# ...

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# * Missing values in the Keyless_Entry and Central_Locking columns can be imputed using a groupby operation based on Make and Model.

# %%
for col in cols:
    ob_df[col] = ob_df[col].fillna(
        ob_df.groupby(["Make", "Model"])[col].transform(
            lambda x: x.mode().iloc[0] if not x.mode().empty
            else np.nan))

# %%
for col in cols:
    print(f"Total number of missing values in {col} column: {ob_df[col].isna().sum()}")
    print("-"*80)
# Out:
# Total number of missing values in Keyless_Entry column: 78
# --------------------------------------------------------------------------------
# Total number of missing values in Central_Locking column: 43
# --------------------------------------------------------------------------------

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# * Despite applying the groupby-based imputation, some values remain missing.
# * These values are therefore filled with **"Undefined"** to ensure that no incorrect assumptions are introduced into the dataset

# %%
for col in cols:
    ob_df[col] = ob_df[col].fillna(value = "Undefined")

# %% [markdown]
# #### Missing values in Keyless_Entry and Central_Locking columns

# %%
for col in cols:
    print(f"Total number of missing values in {col} column: {ob_df[col].isna().sum()}")
    print("-"*80)
# Out:
# Total number of missing values in Keyless_Entry column: 0
# --------------------------------------------------------------------------------
# Total number of missing values in Central_Locking column: 0
# --------------------------------------------------------------------------------

# %% [markdown]
# -----

# %% [markdown]
# <div style="background-color:lightgreen; padding:15px; border-radius:8px;">
#   <h2 style="text-align:center; margin:0;">Cleaning "Start_/_Stop_Button",
#     "Infotainment_Screen",
#     "Navigation_System",
#     "Bluetooth"
#  columns</h2>
# </div>

# %% [markdown]
# -----

# %% [markdown]
# ### 01. Cleaning Start_/_Stop_Button and Infotainment_Screen columns.

# %%
cols = ["Start_/_Stop_Button", "Infotainment_Screen",]

# %% [markdown]
# #### Displaying sample values

# %%
ob_df[cols].sample(5)
# Out:
#      Start_/_Stop_Button Infotainment_Screen
# 578                  NaN     Touch Sensitive
# 448                  NaN                 NaN
# 737                  Yes                 NaN
# 880                  Yes     Touch Sensitive
# 1226                 Yes                 NaN

# %% [markdown]
# #### Missing value in Start_/_Stop_Button and Infotainment_Screen column

# %%
for col in cols:
    print(f"Total number of missing values of {col} column: {ob_df[col].isna().sum()}")
    print("-"*80)
# Out:
# Total number of missing values of Start_/_Stop_Button column: 676
# --------------------------------------------------------------------------------
# Total number of missing values of Infotainment_Screen column: 462
# --------------------------------------------------------------------------------

# %% [markdown]
# #### Displaying unique values of Start_/_Stop_Button and Infotainment_Screen column

# %%
for col in cols:
    print(f"Unique values of {col} column: {ob_df[col].unique()}")
    print("-"*80)
# Out:
# Unique values of Start_/_Stop_Button column: <StringArray>
# ['Yes', nan]
# Length: 2, dtype: str
# --------------------------------------------------------------------------------
# Unique values of Infotainment_Screen column: <StringArray>
# [nan, 'Touch Sensitive', 'Yes']
# Length: 3, dtype: str
# --------------------------------------------------------------------------------

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# * The **Start/Stop_Button** column contains only **two values**, one of which is a **missing value**.
# If we apply a groupby operation using the **Make** and **Model** columns, all missing values would be filled with **Yes**,
# which could be **incorrect for certain cars**.
#
# * A similar issue exists with the **Infotainment_Screen** column, which has only **three values**, including a **missing value**.
# Using groupby-based imputation in this case would fill every missing value with either **Yes** or **Touch Sensitive**,
# potentially leading to **wrong assumptions** about those vehicles.
#
# * Therefore, to **avoid introducing incorrect information**, the missing values in these columns are filled with **Undefined**,
# ensuring that no **unverified assumptions** are made about the features.

# %% [markdown]
# #### Filling missing values

# %%
for col in cols:
    ob_df[col] = ob_df[col].fillna(value = "Undefined")

# %% [markdown]
# #### Missing value in Start_/_Stop_Button and Infotainment_Screen column

# %%
for col in cols:
    print(f"Total number of missing values of {col} column: {ob_df[col].isna().sum()}")
    print("-"*80)
# Out:
# Total number of missing values of Start_/_Stop_Button column: 0
# --------------------------------------------------------------------------------
# Total number of missing values of Infotainment_Screen column: 0
# --------------------------------------------------------------------------------

# %% [markdown]
# -----

# %% [markdown]
# ### 02. Cleaning Navigation_System and Bluetooth column

# %%
cols = [ "Navigation_System", "Bluetooth"]

# %% [markdown]
# #### Displaying sample values

# %%
ob_df[cols].sample(5)
# Out:
#      Navigation_System Bluetooth
# 671                Yes       Yes
# 702                NaN       Yes
# 348                Yes       Yes
# 1080               NaN       Yes
# 793                Yes       Yes

# %% [markdown]
# #### Missing value in Navigation_System and Bluetooth column

# %%
for col in cols:
    print(f"Total number of missing values of {col} column: {ob_df[col].isna().sum()}")
    print("-"*80)
# Out:
# Total number of missing values of Navigation_System column: 593
# --------------------------------------------------------------------------------
# Total number of missing values of Bluetooth column: 292
# --------------------------------------------------------------------------------

# %% [markdown]
# #### Displaying unique values of Navigation_System and Bluetooth column

# %%
for col in cols:
    print(f"Unique values of {col} column: {ob_df[col].unique()}")
    print("-"*80)
# Out:
# Unique values of Navigation_System column: <StringArray>
# [nan, 'Yes']
# Length: 2, dtype: str
# --------------------------------------------------------------------------------
# Unique values of Bluetooth column: <StringArray>
# ['Yes', nan]
# Length: 2, dtype: str
# --------------------------------------------------------------------------------

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# * In both **Navigation_System** and **Bluetooth** columns, we have only **two unique values**, one of which is a **missing value**.
# If we perform a groupby operation using the **Make** and **Model** columns, all missing values would be filled with **Yes**,
# which could be a **wrong value for that car**.
#
# * Therefore, we fill the missing values with **"Undefined"** so that we **do not make wrong assumptions** about the car.

# %% [markdown]
# #### Filling missing values in Navigation_System and Bluetooth column

# %%
for col in cols:
    ob_df[col] = ob_df[col].fillna(value = "Undefined")

# %% [markdown]
# #### Missing value in Navigation_System and Bluetooth column

# %%
for col in cols:
    print(f"Total number of missing values of {col} column: {ob_df[col].isna().sum()}")
    print("-"*80)
# Out:
# Total number of missing values of Navigation_System column: 0
# --------------------------------------------------------------------------------
# Total number of missing values of Bluetooth column: 0
# --------------------------------------------------------------------------------

# %% [markdown]
# -----

# %% [markdown]
# <div style="background-color:lightgreen; padding:15px; border-radius:8px;">
#   <h2 style="text-align:center; margin:0;">Cleaning         "Multifunction_Steering_Wheel",
#     "Automatic_Headlamps",
#     "Rain_Sensing_Wipers",
#  columns</h2>
# </div>

# %% [markdown]
# ### Cleaning all the remaning columns

# %%
cols = ["Multifunction_Steering_Wheel", "Automatic_Headlamps", "Rain_Sensing_Wipers"]

# %% [markdown]
# #### Displaying sample values

# %%
ob_df[cols].sample(5)
# Out:
#       Multifunction_Steering_Wheel Automatic_Headlamps Rain_Sensing_Wipers
# 201   Multifunction Steering Wheel                 NaN                 NaN
# 311   Multifunction Steering Wheel                 Yes                 Yes
# 1267  Multifunction Steering Wheel                 NaN                 NaN
# 922                            NaN                 NaN                 NaN
# 197                            NaN                 NaN                 NaN

# %% [markdown]
# #### Missing value in Multifunction_Steering_Wheel, Automatic_Headlamps	and Rain_Sensing_Wipers column

# %%
for col in cols:
    print(f"Total number of missing values of {col} column: {ob_df[col].isna().sum()}")
    print("-"*80)
# Out:
# Total number of missing values of Multifunction_Steering_Wheel column: 351
# --------------------------------------------------------------------------------
# Total number of missing values of Automatic_Headlamps column: 773
# --------------------------------------------------------------------------------
# Total number of missing values of Rain_Sensing_Wipers column: 798
# --------------------------------------------------------------------------------

# %% [markdown]
# #### Displaying unique values of Multifunction_Steering_Wheel, Automatic_Headlamps and Rain_Sensing_Wipers column

# %%
for col in cols:
    print(f"Unique values of {col} column: {ob_df[col].unique()}")
    print("-"*80)
# Out:
# Unique values of Multifunction_Steering_Wheel column: <StringArray>
# [                                                    nan,
#                           'Multifunction Steering Wheel',
#                                                    'Yes',
#  'Multifunction Steering Wheel, With gear shift paddles',
#  'With gear shift paddles, Multifunction Steering Wheel',
#                                'With gear shift paddles']
# Length: 6, dtype: str
# --------------------------------------------------------------------------------
# Unique values of Automatic_Headlamps column: <StringArray>
# [nan, 'Yes']
# Length: 2, dtype: str
# --------------------------------------------------------------------------------
# Unique values of Rain_Sensing_Wipers column: <StringArray>
# [nan, 'Yes']
# Length: 2, dtype: str
# --------------------------------------------------------------------------------

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# * Since the number of missing values is **high** in each column and the number of **unique values is low**, we fill these missing values with **Undefined** to ensure that no **incorrect assumptions** are made about the cars.

# %% [markdown]
# #### Filling missing values in Multifunction_Steering_Wheel, Automatic_Headlamps and Rain_Sensing_Wipers column

# %%
for col in cols:
    ob_df[col] = ob_df[col].fillna(value = "Undefined")

# %% [markdown]
# #### Missing value in Multifunction_Steering_Wheel, Automatic_Headlamps	and Rain_Sensing_Wipers column

# %%
for col in cols:
    print(f"Total number of missing values of {col} column: {ob_df[col].isna().sum()}")
    print("-"*80)
# Out:
# Total number of missing values of Multifunction_Steering_Wheel column: 0
# --------------------------------------------------------------------------------
# Total number of missing values of Automatic_Headlamps column: 0
# --------------------------------------------------------------------------------
# Total number of missing values of Rain_Sensing_Wipers column: 0
# --------------------------------------------------------------------------------

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# * We have completed the **categorical data cleaning**.
# * In the **next step**, we will clean the **numerical data frame**.

# %% [markdown]
# -----

# %% [markdown]
# <a id="1"></a>
# # <div style="padding:20px;color:white;margin:0;font-size:35px;font-family:Verdana;text-align:center;display:fill;border-radius:5px;background-color:#254E58;overflow:hidden"><b>🧼 Cleaning Numerical Data-Frame 🧼</b></div>

# %% [markdown]
# -----

# %% [markdown]
# ### 1. Displaying Random Sample of Numerical Data-Frame.

# %%
num_df.sample(5)
# Out:
#       Cylinders  Valves_Per_Cylinder  Doors  Seating_Capacity  \
# 1266        4.0                  4.0    4.0               5.0
# 674         4.0                  4.0    5.0               7.0
# 5           2.0                  2.0    5.0               4.0
# 1156        6.0                  4.0    4.0               4.0
# 433         3.0                  4.0    5.0               5.0
#
#       Number_of_Airbags
# 1266                2.0
# 674                 6.0
# 5                   NaN
# 1156                6.0
# 433                 2.0

# %% [markdown]
# ### 2. Computing Total No. of Missing Values and  their % .

# %%
null_df = num_df.isnull().sum().to_frame().rename(columns={0:"Total No. of Missing Values"})
null_df["% of Missing Values"] = round((100*null_df["Total No. of Missing Values"])/len(num_df),2)
null_df
# Out:
#                      Total No. of Missing Values  % of Missing Values
# Cylinders                                     66                 5.21
# Valves_Per_Cylinder                          102                 8.05
# Doors                                          4                 0.32
# Seating_Capacity                               6                 0.47
# Number_of_Airbags                            135                10.66

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# * **5 out of 5 Features are having Missing values.** But the **% of Missing values is very low.**
# * So **instead of dropping** these records we can **fill them with suitable values.**

# %% [markdown]
# ### 3.Displaying Unique values of all numerical Data-Frame columns

# %%
cols = num_df.columns.tolist()

for col in cols:
    print(f"Unique values of {col} column: {num_df[col].unique()}")
    print("-"*100)
# Out:
# Unique values of Cylinders column: [ 2.  3.  4. nan  5.  6.  8. 12. 10. 16.]
# ----------------------------------------------------------------------------------------------------
# Unique values of Valves_Per_Cylinder column: [ 2.  4. 12. nan 16.  8.  1.  6.  3.]
# ----------------------------------------------------------------------------------------------------
# Unique values of Doors column: [ 5.  4. nan  2.  3.]
# ----------------------------------------------------------------------------------------------------
# Unique values of Seating_Capacity column: [ 4.  5.  7. nan  2.  6.  9.  8. 16.]
# ----------------------------------------------------------------------------------------------------
# Unique values of Number_of_Airbags column: [nan  1.  2.  4.  6.  9.  8.  7. 10.  5.  3. 14.]
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# * **Missing values** in each column can be **imputed using the column’s median**.

# %% [markdown]
# ### 4.Filling Missing values with each column Median

# %%
for col in cols:
    num_df[col] = num_df[col].fillna(value = df.groupby(["Make", "Model"])[col].transform("median"))
    num_df[col] = num_df[col].fillna(value = num_df[col].median())

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# * We fill the **missing values** of each **numerical column** using the **group-wise median**, based on the **Make** and **Model** columns.
#
# * After that, any remaining **missing values** are filled using the **overall median of each column**.

# %% [markdown]
# ### 5.Missing values in Numerical Data-Frame

# %%
num_df.isna().sum().to_frame(name = "Missing values")
# Out:
#                      Missing values
# Cylinders                         0
# Valves_Per_Cylinder               0
# Doors                             0
# Seating_Capacity                  0
# Number_of_Airbags                 0

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# * We are done with **all the cleaning part.**
# * In the **next-step** we can simply concatenate **both the data-frame.**

# %% [markdown]
# -----

# %% [markdown]
# <a id="1"></a>
# # <div style="padding:20px;color:white;margin:0;font-size:35px;font-family:Verdana;text-align:center;display:fill;border-radius:5px;background-color:#254E58;overflow:hidden"><b>🛠 Joining Both the Data-Frames 🛠</b></div>

# %% [markdown]
# ----

# %%
df = pd.concat([num_df, ob_df], axis=1)

# %% [markdown]
# ### 1. Checking the Dimension.

# %%
df.shape
# Out:
# (1267, 52)

# %% [markdown]
# ### 2. Displaying Random Sample.

# %% [markdown]
# ### 3. Assigning Suitable Names for "Make" & "Model" Columns.

# %%
df.rename(columns= {"Make":"Car Manufacturer", "Model":"Car Model"}, inplace = True)

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# * We have completed **joining both DataFrames**.
# * The **next step** is **Exploratory Data Analysis (EDA)**.

# %% [markdown]
# -----

# %% [markdown]
# <a id="1"></a>
# # <div style="padding:20px;color:white;margin:0;font-size:35px;font-family:Verdana;text-align:center;display:fill;border-radius:5px;background-color:#254E58;overflow:hidden"><b>📊 Exploratory Data Analysis 📊</b></div>

# %% [markdown]
# -----

# %% [markdown]
# <a id="1.3"></a>
# <h2 style="font-family: Verdana; font-size: 22px; font-style: normal; font-weight: normal; text-decoration: none; text-transform: none; letter-spacing: 2px; color: black; background-color: #ffffff;"><b>1.🔍</b>Visualizing <b>Ex-Showroom Price Distribution.</b></h2>

# %%
plt.figure(figsize=(15,6))
sns.boxplot(x = df["Ex-Showroom_Price"], palette= "Set2")
plt.title("Ex-Showroom_Price", fontweight= "black", size = 20, pad = 15)
plt.show()

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# * There **two cars** with **extremly high ex-showroom price** which can be considered as **extreme outliers.**
# * So for **better analysis** we can simply **drop these features.**

# %%
df[df["Ex-Showroom_Price"]>150000000][["Car Manufacturer", "Car Model"]]
# Out:
#     Car Manufacturer Car Model
# 355          Bugatti    Chiron
# 356          Bugatti    Chiron

# %%
df.drop(index= [355, 356], inplace= True)

# %% [markdown]
# -----

# %% [markdown]
# <a id="1.3"></a>
# <h2 style="font-family: Verdana; font-size: 22px; font-style: normal; font-weight: normal; text-decoration: none; text-transform: none; letter-spacing: 2px; color: black; background-color: #ffffff;"><b>2.🔍</b>Visualizing <b>Average price by car manufacturer.</b></h2>

# %%
average_price = df.groupby(["Car Manufacturer"])["Ex-Showroom_Price"].mean().sort_values(ascending = False)

expensive_cars = average_price[:15]
regular_cars = average_price[15:]
cols = [expensive_cars, regular_cars]

colors = ["Reds", "Greens"]

title = ["Top 15 High-Priced Car Manufacturers", "Low-Priced Car Manufacturers"]

plt.figure(figsize=(15,6))
for index, col in enumerate(cols):
    plt.subplot(1,2,index+1)
    sns.barplot(x = col.index, y = col.values, palette= sns.color_palette(colors[index],len(col))[::-1] )
    plt.title(f"{title[index]}", fontweight = "black", size= 20, pad= 15)
    plt.ylabel("Median Ex-Showroom Price")
    plt.xticks(rotation = 90)
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# * **Car prices** show strong **right-skewness**, driven by a **small number of luxury manufacturers.**
#
# * A **clear segmentation** exists between **premium** and **mass-market manufacturers**, justifying **segment-wise analysis.**

# %% [markdown]
# -----

# %% [markdown]
# <a id="1.3"></a>
# <h2 style="font-family: Verdana; font-size: 22px; font-style: normal; font-weight: normal; text-decoration: none; text-transform: none; letter-spacing: 2px; color: black; background-color: #ffffff;"><b>3.🔍</b>Visualizing <b>Displacement, Power & Torque Features.</b></h2>

# %%
cols = ["Displacement (cc)", "Power (HP)", "Torque (Nm)"]

plt.figure(figsize=(15,6))
for index, col in enumerate(cols):
    plt.subplot(1,3,index+1)
    sns.regplot(data = df, x = col, y = "Ex-Showroom_Price", line_kws={"color" : "red", "lw" : 3}, scatter_kws={"color" : "black", "alpha" : 0.5})
    plt.title(f'{col} Vs Car Price', fontweight= "black", size = 15, pad = 20)
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# * We can clearly observe that **Displacement**, **Power**, and **Torque** are **highly correlated** with **Car Price**.
#
# * As the values of these engine-related features increase, the **car price also increases**, indicating a strong **positive relationship** between engine performance and pricing.
#
# * Therefore, these features should be **retained** in the dataset, as they significantly influence car price and are important predictors for further analysis and model building.

# %% [markdown]
# -----

# %% [markdown]
# <a id="1.3"></a>
# <h2 style="font-family: Verdana; font-size: 22px; font-style: normal; font-weight: normal; text-decoration: none; text-transform: none; letter-spacing: 2px; color: black; background-color: #ffffff;"><b>4.🔍</b>Visualizing <b>Length, Width & Height Features.</b></h2>

# %%
cols = ["Length", "Width", "Height"]

plt.figure(figsize=(15,6))
for index, col in enumerate(cols):
    plt.subplot(1,3, index+1)
    sns.regplot(data = df, x = col, y = "Ex-Showroom_Price", line_kws={"color" : "red", "lw" : 3}, scatter_kws= {"color" : "black", "alpha" : .5})
    plt.title(f'{col} Vs Car Price', fontweight = "black", size = 20, pad = 15)

plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# - **Length and width** are positively associated with ex-showroom price and reflect premium vehicle positioning.
# - **Height alone** does not contribute significantly to higher pricing.
# - While dimensional features influence price, **engine specifications and brand value** likely play a stronger role in determining car prices.

# %% [markdown]
# -----

# %% [markdown]
# <a id="1.3"></a>
# <h2 style="font-family: Verdana; font-size: 22px; font-style: normal; font-weight: normal; text-decoration: none; text-transform: none; letter-spacing: 2px; color: black; background-color: #ffffff;"><b>5.🔍</b>Visualizing <b>Wheelbase, Kerb_Weight & Ground_Clearance Features.</b></h2>

# %%
cols = ["Wheelbase", "Kerb_Weight", "Ground_Clearance"]

plt.figure(figsize=(15,6))
for index, col in enumerate(cols):
    plt.subplot(1,3,index+1)
    sns.regplot(data= df, x= col, y= "Ex-Showroom_Price", line_kws={"color" : "red", "lw" : 3}, scatter_kws={"color" : "black", "alpha" : .5})
    plt.title(f'{col} Vs Car Price', fontweight = "black", size = 15, pad= 15)
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
#
# * Wheelbase and Kerb Weight show a **strong positive influence** on car price, whereas Ground Clearance has a **comparatively weaker impact**.
# These features should be retained for further analysis, especially when building predictive models.

# %% [markdown]
# -----

# %% [markdown]
# <a id="1.3"></a>
# <h2 style="font-family: Verdana; font-size: 22px; font-style: normal; font-weight: normal; text-decoration: none; text-transform: none; letter-spacing: 2px; color: black; background-color: #ffffff;"><b>6.🔍</b>Visualizing <b>Fuel_Tank_Capacity, Boot_Space & ARAI_Certified_Mileage Features.</b></h2>

# %%
cols = ["Fuel_Tank_Capacity", "Boot_Space", "ARAI_Certified_Mileage"]

plt.figure(figsize=(15,6))
for index, col in enumerate(cols):
    plt.subplot(1,3,index+1)
    sns.regplot(data= df, x= col, y= "Ex-Showroom_Price", line_kws={"color" : "red", "lw" : 3}, scatter_kws={"color" : "black", "alpha" : .5})
    plt.title(f'{col} Vs Car Price', fontweight = "black", size = 15, pad= 15)
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
#
# * Fuel Tank Capacity shows a **moderate impact** on car price, Boot Space has a **minimal influence**, and ARAI Certified Mileage exhibits a **negative relationship** with price.
# * These features should be interpreted in combination with other variables such as **engine performance and vehicle segment**.

# %% [markdown]
# -----

# %% [markdown]
# <a id="1.3"></a>
# <h2 style="font-family: Verdana; font-size: 22px; font-style: normal; font-weight: normal; text-decoration: none; text-transform: none; letter-spacing: 2px; color: black; background-color: #ffffff;"><b>7.🔍</b>Visualizing <b>City_Mileage & Highway_Mileage Features.</b></h2>

# %%
cols = ["City_Mileage", "Highway_Mileage"]

plt.figure(figsize=(15,6))
for index, col in enumerate(cols):
    plt.subplot(1,2,index+1)
    sns.regplot(data= df, x= col, y= "Ex-Showroom_Price", line_kws={"color" : "red", "lw" : 3}, scatter_kws={"color" : "black", "alpha" : .5})
    plt.title(f'{col} Vs Car Price', fontweight = "black", size = 15, pad= 15)
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
#
#
# * Mileage-related features tend to show a **negative correlation** with car price, reflecting a trade-off between **fuel efficiency and vehicle performance**.
# * However, City Mileage requires additional cleaning due to extreme outliers before it can be reliably used in further analysis.

# %% [markdown]
# -----

# %% [markdown]
# <a id="1.3"></a>
# <h2 style="font-family: Verdana; font-size: 22px; font-style: normal; font-weight: normal; text-decoration: none; text-transform: none; letter-spacing: 2px; color: black; background-color: #ffffff;"><b>8.🔍</b>Visualizing <b>Cylinders, Valves_Per_Cylinder & Doors Features.</b></h2>

# %%
cols = ["Cylinders", "Valves_Per_Cylinder", "Doors"]

plt.figure(figsize=(15,6))
for index, col in enumerate(cols):
    plt.subplot(1,3,index+1)
    sns.boxplot(data= df, x= col, y= "Ex-Showroom_Price", palette= "Set1")
    plt.title(f'{col} Vs Car Price', fontweight= "black", pad= 15)
plt.tight_layout()

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
#
# * Car price increases significantly with a higher **number of cylinders**, indicating a strong association with performance and luxury vehicles.
# * **Valves per cylinder** show a moderate impact on price, reflecting differences in engine efficiency and performance.
# * Cars with **2 doors** generally have higher prices, while **4–5 door** vehicles are mostly concentrated in the budget to mid-range segments.

# %% [markdown]
# ----

# %% [markdown]
# <a id="1.3"></a>
# <h2 style="font-family: Verdana; font-size: 22px; font-style: normal; font-weight: normal; text-decoration: none; text-transform: none; letter-spacing: 2px; color: black; background-color: #ffffff;"><b>9.🔍</b>Visualizing <b>Seating_Capacity, Number_of_Airbags & Gears Features.</b></h2>

# %%
cols = ["Seating_Capacity", "Number_of_Airbags", "Gears"]

plt.figure(figsize=(15,6))
for index,col in enumerate(cols):
    plt.subplot(1,3,index+1)
    sns.boxplot(data=df, x=col, y= "Ex-Showroom_Price" ,palette= "Set1")
    plt.title(f'{col} Vs Car Price', fontweight= "black", pad= 15)
plt.tight_layout()

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
#
#
# * Cars with **lower seating capacity (2–4 seats)** tend to have **higher prices**, reflecting sports and premium segments, while higher seating capacity vehicles are mostly budget-oriented.
# * An increase in the **number of airbags** is associated with **higher car prices**, indicating the importance of safety features.
# * Vehicles with **more gears** generally have higher prices, as they are linked to advanced transmissions and better performance.

# %% [markdown]
# ----

# %% [markdown]
# <a id="1.3"></a>
# <h2 style="font-family: Verdana; font-size: 22px; font-style: normal; font-weight: normal; text-decoration: none; text-transform: none; letter-spacing: 2px; color: black; background-color: #ffffff;"><b>10.🔍</b>Visualizing <b>Fuel_Type & Body_Type Features.</b></h2>

# %%
cols = ["Fuel_Type","Body_Type"]
plt.figure(figsize=(13,5))

for index, col in enumerate(cols):
    plt.subplot(1,2,index+1)
    sns.boxplot(x = col, y = "Ex-Showroom_Price", data = df, palette="hls")
    plt.title(f"{col} vs Car Price", fontweight = "black", size =20, pad =20)
    plt.xticks(rotation=90)
plt.tight_layout()

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
#
# - **Hybrid** and **Electric** vehicles are priced higher, while **CNG** variants remain **budget-oriented**.
# - **SUVs**, **Coupes**, **Convertibles**, and **Sports cars** command higher prices than **Hatchbacks** and **Sedans**.
# - **Fuel type** and **Body type** significantly influence **Ex-Showroom pricing**.
# `

# %% [markdown]
# <a id="1.3"></a>
# <h2 style="font-family: Verdana; font-size: 20px; font-style: normal; font-weight: normal; text-decoration: none; text-transform: none; letter-spacing: 1px; color: black; background-color: #ffffff;"><b>11.🔍</b>Visualizing <b>Cycliner_Configuration & Keyless_Entry Features.</b></h2>

# %%
cols = ["Cylinder_Configuration", "Keyless_Entry"]

plt.figure(figsize=(15,6))
for index, col in enumerate(cols):
    plt.subplot(1,2,index+1)
    sns.boxplot(x = col, y = "Ex-Showroom_Price", data = df, palette="hls")
    plt.title(f"{col} vs Car Price", fontweight = "black", size =20, pad =20)
    plt.xticks(rotation=90)
plt.tight_layout()

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
#
#
# - **V, Flat, and W engine configurations** are associated with higher ex-showroom prices than **Inline engines**.
# - Vehicles with **Smart Key entry systems** tend to be priced higher than those with basic keyless options.

# %% [markdown]
# <a id="1"></a>
# # <div style="padding:20px;color:white;margin:0;font-size:35px;font-family:Verdana;text-align:center;display:fill;border-radius:5px;background-color:#254E58;overflow:hidden"><b>📁 Saving Cleaned Dataset 📁</b></div>

# %%
df.to_csv(r"C:\Users\mohit\OneDrive\Desktop\PYTHON\clean_car_data.csv", index=False)

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# * After completing **data cleaning** and **preprocessing**, the **final structured dataset** is exported in **CSV format** to enable **advanced analytics** and **interactive dashboard creation** in **Power BI**.

# %% [markdown]
# <a id="1"></a>
# # <div style="padding:20px;color:white;margin:0;font-size:35px;font-family:Verdana;text-align:center;display:fill;border-radius:5px;background-color:#254E58;overflow:hidden"><b>🔍 Conclusion 🔍</b></div>

# %% [markdown]
# <div style="border-radius:10px; border:black solid; padding: 15px; background-color: white; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Key-Points:</font></h3>
#
# <div style="font-family:Georgia;background-color:'#DEB887'; padding:30px; font-size:17px">
#
#
#
# - The exploratory data analysis reveals that **car price is strongly influenced by engine performance and vehicle size**, with features such as **Displacement, Power, Torque, Cylinders, Kerb Weight, and Wheelbase** showing strong positive relationships with price.
# **Luxury and performance-oriented vehicles** consistently occupy the higher price range, while mass-market cars cluster in the lower to mid-price segments.
#
# - **Mileage-related features** (ARAI, City, Highway) exhibit a **negative relationship** with price, highlighting the trade-off between fuel efficiency and performance.
# **Safety and convenience features** such as **Number of Airbags, Transmission type, and Keyless Entry** are more prevalent in higher-priced vehicles, indicating their role in premium positioning.
#
# - Categorical analysis shows clear **brand and segment differentiation**, where manufacturers like **Rolls-Royce, Ferrari, and Bentley** dominate the premium segment, while **Maruti Suzuki, Tata, and Hyundai** focus on affordability.
# High-cardinality features such as **Car Model and Variant** were handled carefully to avoid noisy interpretations.
#
# - Overall, the dataset is well-structured and provides meaningful insights into the **technical, dimensional, safety, and market factors** affecting car prices, forming a strong foundation for feature selection and predictive modeling.
